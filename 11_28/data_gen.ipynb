# %% [markdown]
# # Notes:
# has sentiment analysis (at bottom)
#
# 1 day predictions with all previous data
#
# erraneous due to small data size

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pywt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, Flatten, RepeatVector
from tensorflow.keras.callbacks import EarlyStopping
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import requests,os
from datetime import datetime, timedelta
# Helper Function to fetch historical stock data
import yfinance as yf
def get_stock_data(ticker, start_date, end_date):
    try:
        # https://medium.com/nerd-for-tech/all-you-need-to-know-about-yfinance-yahoo-finance-library-fa4c6e48f08e
        #data = yf.Ticker(ticker).history(start=start_date, end=end_date)  
        data = yf.download(ticker, start=start_date, end=end_date)
        return data
    except Exception as e:
        return f"Error fetching data: {e}"
    
    
# Sentiment 
def fetch_news_and_sentiment(ticker, start_date, end_date):
    api_url = f"https://newsapi.org/v2/everything?q={ticker}&from={start_date}&to={end_date}&apiKey=7e9676fa277d423f8deff9a4894bd717"
    response = requests.get(api_url)
    news_data = response.json()

    headlines = []
    dates = []
    if "articles" in news_data:
        for article in news_data['articles']:
            headlines.append(article['title'])
            # Extract the publication date of the article
            dates.append(article['publishedAt'][:10])  # Extract the YYYY-MM-DD format

    # Perform sentiment analysis using VADER
    analyzer = SentimentIntensityAnalyzer()
    sentiment_data = []
    for headline, date in zip(headlines, dates):
        score = analyzer.polarity_scores(headline)
        sentiment_data.append({'date': date, 'sentiment': score['compound']})  # Store date and compound score

    return sentiment_data

# Function to aggregate daily sentiment scores
def aggregate_daily_sentiment(sentiment_data, start_date, end_date):
    # Convert to DataFrame
    sentiment_df = pd.DataFrame(sentiment_data)
    # print(sentiment_df[:30])
    sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])

    # Group by date and calculate the average sentiment for each day
    daily_sentiment = (
        sentiment_df.groupby('date')['sentiment']
        .mean()
        .reindex(pd.date_range(start_date, end_date), fill_value=0)  # Fill missing days with 0 sentiment
    )
    print(daily_sentiment)
    return daily_sentiment
# Data Preprocessing Function
def preprocess_data(df, ticker, start_date, end_date, wavelet_transform=False, sentiment=False, seq_length=5):
    # Normalize Close prices
    scaler_close = MinMaxScaler(feature_range=(0, 1))
    df['Close_scaled'] = scaler_close.fit_transform(df['Close'].values.reshape(-1, 1))

    # Optionally apply Wavelet Transform to Close prices
    if wavelet_transform:
        wavelet = pywt.Wavelet('db6')
        def wavelet_transform(data, lvl=8):
            coeff = pywt.wavedec(data, wavelet, mode='symmetric', level=lvl)
            return coeff
        def inverse_wavelet_transform(coeff):
            for i in range(3):
                coeff[-(i + 1)] = np.zeros_like(coeff[-(i + 1)])
            return pywt.waverec(coeff, wavelet, mode='symmetric')
        
        close_prices = df['Close'].values
        wavelet_coeff = wavelet_transform(close_prices)
        reconstructed_close = inverse_wavelet_transform(wavelet_coeff)
        
        # Adjust the reconstructed data length to match the original DataFrame
        # reconstructed_close = np.pad(reconstructed_close, (0, len(df) - len(reconstructed_close)), mode='edge')
        reconstructed_close = np.pad(reconstructed_close, (0, max(0, len(df) - len(reconstructed_close))), mode='edge')

        df['Close_scaled'] = scaler_close.fit_transform(reconstructed_close.reshape(-1, 1))

    # Optionally include Sentiment data
    if sentiment:
        sentiment_data = fetch_news_and_sentiment(ticker, start_date, end_date)

        # Aggregate daily sentiment scores
        daily_sentiment_scores = aggregate_daily_sentiment(sentiment_data, start_date, end_date)

        df.index = pd.to_datetime(df.index)  # Convert stock_data index to datetime
        daily_sentiment_scores.index = pd.to_datetime(daily_sentiment_scores.index)  # Convert daily_sentiment index to datetime

        # Replace the "Sentiment" column in stock_data with values from daily_sentiment
        df['Sentiment'] = df.index.map(daily_sentiment_scores.get)

        # Fill any missing sentiment values with 0
        df['Sentiment'].fillna(0, inplace=True)

        scaler_sentiment = MinMaxScaler(feature_range=(0, 1))
        df['Sentiment_scaled'] = scaler_sentiment.fit_transform(df['Sentiment'].values.reshape(-1, 1))
        features = df[['Close_scaled', 'Sentiment_scaled']].values
    else:
        features = df[['Close_scaled']].values

    # Create sequences for LSTM
    X, y = [], []
    for i in range(len(features) - seq_length):
        X.append(features[i:i + seq_length])
        y.append(features[i + seq_length, 0])  # Target is the next Close value
    return np.array(X), np.array(y), scaler_close

# Build LSTM Model
# def build_lstm_model(input_shape, return_sequences=False):
#     model = Sequential([
#         Bidirectional(LSTM(units=256, return_sequences=True, input_shape=input_shape)),
#         Dropout(0.3),
#         Bidirectional(LSTM(units=128, return_sequences=return_sequences)),
#         Dropout(0.3),
#         RepeatVector(1),
#         Dense(units=64, activation='relu'),
#         Dense(units=32),
#         Flatten(),
#         Dense(units=1)
#     ])
#     model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
#     return model
def build_lstm_model(input_shape, return_sequences=False):
    model = Sequential([
        Bidirectional(LSTM(units=256, return_sequences=True, input_shape=input_shape)),
        Dropout(0.3),
        Bidirectional(LSTM(units=128, return_sequences=True)),  # Ensure return_sequences=True for repeat vector
        Dropout(0.3),
        Flatten(),  # Flatten the 3D output to 2D
        RepeatVector(1),
        Dense(units=64, activation='relu'),
        Dense(units=32),
        Flatten(),
        Dense(units=1)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    return model

# Train Model and Get Predictions
def train_and_predict(X_train, y_train, X_test, y_test, model, scaler_close):
    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Train the model
    model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

    # Make predictions
    train_predictions = model.predict(X_train)
    test_predictions = model.predict(X_test)

    # Inverse transform predictions and true values
    train_predictions = scaler_close.inverse_transform(train_predictions)
    test_predictions = scaler_close.inverse_transform(test_predictions)
    y_train = scaler_close.inverse_transform(y_train.reshape(-1, 1))
    y_test = scaler_close.inverse_transform(y_test.reshape(-1, 1))

    return train_predictions, test_predictions, y_train, y_test

# Calculate Metrics
def calculate_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    return mae, mse, rmse, r2

# Plot Results
def plot_results(df, seq_length, split, y_train, train_predictions, y_test, test_predictions, ticker, model_type):
    plt.figure(figsize=(14, 7))
    plt.plot(df.index[seq_length:split + seq_length], y_train, label='Train Actual', color='blue')
    plt.plot(df.index[seq_length:split + seq_length], train_predictions, label='Train Predicted', color='cyan')
    plt.plot(df.index[split + seq_length:], y_test, label='Test Actual', color='green')
    plt.plot(df.index[split + seq_length:], test_predictions, label='Test Predicted', color='red')
    plt.legend()
    plt.title(f"{ticker} - {model_type}: Predictions vs Actual")
    plt.xlabel("Time")
    plt.ylabel("Stock Price")
    directory = f"data/{ticker}/{model_type}"
    os.makedirs(directory, exist_ok=True)
    plt.savefig(directory)
    plt.show()


# Consolidated Function to Handle Multiple Tickers
def run_models_for_tickers(tickers, models=['LSTM', 'LSTM + Wavelet', 'LSTM + Sentiment', 'LSTM + Wavelet + Sentiment'], metrics=['MAE', 'MSE', 'RMSE', 'R2'], seq_length=5): # '
    results = []

    for ticker in tickers:
        start_date = "2024-10-29"
        end_date = "2024-11-28"
        df = get_stock_data(ticker,start_date,end_date)  # Assume a function to load stock data for each ticker
        print(f"Processing {ticker}...")
        
        for model_type in models:
            # Preprocess data based on model type
            wavelet_transform = 'Wavelet' in model_type
            sentiment = 'Sentiment' in model_type
            X, y, scaler_close = preprocess_data(df, ticker, start_date, end_date, wavelet_transform=wavelet_transform, sentiment=sentiment, seq_length=seq_length)
            
            # Split data into training and testing sets
            split = int(0.6 * len(X))
            X_train, X_test = X[:split], X[split:]
            y_train, y_test = y[:split], y[split:]

            # if 'Sentiment' in model_type:
            #     scaler_sentiment = MinMaxScaler(feature_range=(0, 1))
            #     df['Sentiment_scaled'] = scaler_sentiment.fit_transform(df['Sentiment'].values.reshape(-1, 1))
            
            # Build and train model
            model = build_lstm_model(input_shape=(seq_length, X.shape[2]), return_sequences=('Wavelet' in model_type))
            train_predictions, test_predictions, y_train, y_test = train_and_predict(X_train, y_train, X_test, y_test, model, scaler_close)
            
            # Calculate metrics
            metrics_results = calculate_metrics(y_test, test_predictions)
            results.append({
                'Ticker': ticker,
                'Model': model_type,
                'MAE': metrics_results[0],
                'MSE': metrics_results[1],
                'RMSE': metrics_results[2],
                'R2': metrics_results[3]
            })

            # Plot results
            plot_results(df, seq_length, split, y_train, train_predictions, y_test, test_predictions, ticker, model_type)

    # Create DataFrame to store results
    results_df = pd.DataFrame(results)
    print(results_df)

# Example Usage
run_models_for_tickers(['TSLA', 'AAPL', 'NVDA', 'GOOG', 'AMZN', 'MSFT','INTC','BIPC'], models=['LSTM', 'LSTM + Wavelet','LSTM + Sentiment', 'LSTM + Wavelet + Sentiment'], metrics=['MAE', 'MSE', 'RMSE', 'R2']) #'LSTM', 'LSTM + Wavelet',
# Out:
# [*********************100%***********************]  1 of 1 completed
# Processing TSLA...
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 100s 100s/step - loss: 0.4343 - mae: 0.6063 - val_loss: 0.3537 - val_mae: 0.5889
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.3086 - mae: 0.5025 - val_loss: 0.1237 - val_mae: 0.3412
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - loss: 0.1915 - mae: 0.3860 - val_loss: 0.0086 - val_mae: 0.0876
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - loss: 0.0827 - mae: 0.2471 - val_loss: 0.2727 - val_mae: 0.5144
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - loss: 0.1158 - mae: 0.2802 - val_loss: 0.3705 - val_mae: 0.6018
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - loss: 0.1157 - mae: 0.2746 - val_loss: 0.2162 - val_mae: 0.4559
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - loss: 0.1063 - mae: 0.2720 - val_loss: 0.0677 - val_mae: 0.2438
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - loss: 0.0665 - mae: 0.2291 - val_loss: 0.0115 - val_mae: 0.0898
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - loss: 0.0595 - mae: 0.2127 - val_loss: 0.0122 - val_mae: 0.0892
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0727 - mae: 0.2367 - val_loss: 0.0245 - val_mae: 0.1287
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0709 - mae: 0.2273 - val_loss: 0.0279 - val_mae: 0.1415
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.0699 - mae: 0.2268 - val_loss: 0.0211 - val_mae: 0.1145
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0699 - mae: 0.2318 - val_loss: 0.0112 - val_mae: 0.0896
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 147s 147s/step - loss: 0.3917 - mae: 0.6077 - val_loss: 0.5673 - val_mae: 0.7529
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 0.2696 - mae: 0.5066 - val_loss: 0.2871 - val_mae: 0.5356
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 0.1503 - mae: 0.3804 - val_loss: 0.0552 - val_mae: 0.2349
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0326 - mae: 0.1797 - val_loss: 0.0341 - val_mae: 0.1844
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 0.0086 - mae: 0.0780 - val_loss: 0.2536 - val_mae: 0.5031
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - loss: 0.0882 - mae: 0.2687 - val_loss: 0.1911 - val_mae: 0.4368
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0691 - mae: 0.2308 - val_loss: 0.0546 - val_mae: 0.2333
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0153 - mae: 0.1043 - val_loss: 9.2958e-04 - val_mae: 0.0302
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - loss: 0.0014 - mae: 0.0346 - val_loss: 0.0141 - val_mae: 0.1189
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0183 - mae: 0.1334 - val_loss: 0.0400 - val_mae: 0.2000
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0259 - mae: 0.1597 - val_loss: 0.0520 - val_mae: 0.2280
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0313 - mae: 0.1755 - val_loss: 0.0458 - val_mae: 0.2141
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0301 - mae: 0.1705 - val_loss: 0.0287 - val_mae: 0.1692
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0197 - mae: 0.1373 - val_loss: 0.0101 - val_mae: 0.1007
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0065 - mae: 0.0792 - val_loss: 3.6035e-04 - val_mae: 0.0190
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0021 - mae: 0.0413 - val_loss: 0.0045 - val_mae: 0.0672
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0019 - mae: 0.0354 - val_loss: 0.0190 - val_mae: 0.1379
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0066 - mae: 0.0714 - val_loss: 0.0310 - val_mae: 0.1758
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.0100 - mae: 0.0898 - val_loss: 0.0314 - val_mae: 0.1771
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.0166 - mae: 0.1187 - val_loss: 0.0187 - val_mae: 0.1366
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0052 - mae: 0.0652 - val_loss: 0.0067 - val_mae: 0.0820
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0070 - mae: 0.0721 - val_loss: 1.8110e-04 - val_mae: 0.0135
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 5.8830e-04 - mae: 0.0194 - val_loss: 0.0018 - val_mae: 0.0424
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.0014 - mae: 0.0291 - val_loss: 0.0076 - val_mae: 0.0873
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0038 - mae: 0.0564 - val_loss: 0.0131 - val_mae: 0.1146
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 0.0063 - mae: 0.0747 - val_loss: 0.0154 - val_mae: 0.1239
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 0.0074 - mae: 0.0806 - val_loss: 0.0137 - val_mae: 0.1170
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0062 - mae: 0.0729 - val_loss: 0.0094 - val_mae: 0.0968
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - loss: 0.0026 - mae: 0.0479 - val_loss: 0.0047 - val_mae: 0.0687
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - loss: 0.0025 - mae: 0.0445 - val_loss: 0.0011 - val_mae: 0.0326
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - loss: 0.0011 - mae: 0.0294 - val_loss: 2.2678e-05 - val_mae: 0.0045
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 3.4838e-04 - mae: 0.0151 - val_loss: 0.0016 - val_mae: 0.0396
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0013 - mae: 0.0337 - val_loss: 0.0040 - val_mae: 0.0631
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0020 - mae: 0.0386 - val_loss: 0.0056 - val_mae: 0.0749
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0028 - mae: 0.0490 - val_loss: 0.0052 - val_mae: 0.0718
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0024 - mae: 0.0461 - val_loss: 0.0032 - val_mae: 0.0570
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0026 - mae: 0.0459 - val_loss: 0.0010 - val_mae: 0.0318
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0018 - mae: 0.0357 - val_loss: 4.3811e-06 - val_mae: 0.0020
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 7.5308e-04 - mae: 0.0210 - val_loss: 6.0510e-04 - val_mae: 0.0244
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - loss: 3.7296e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0456
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 9.5188e-04 - mae: 0.0235 - val_loss: 0.0036 - val_mae: 0.0603
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0027 - mae: 0.0431 - val_loss: 0.0040 - val_mae: 0.0631
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0027 - mae: 0.0354 - val_loss: 0.0033 - val_mae: 0.0572
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0021 - mae: 0.0380 - val_loss: 0.0020 - val_mae: 0.0445
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0028 - mae: 0.0343 - val_loss: 5.7135e-04 - val_mae: 0.0237
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 3.8199e-04 - mae: 0.0159 - val_loss: 8.9365e-06 - val_mae: 0.0022
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 7.3564e-04 - mae: 0.0206 - val_loss: 1.7977e-04 - val_mae: 0.0133
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0017 - mae: 0.0314 - val_loss: 3.8000e-04 - val_mae: 0.0194
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 2024-10-29    0.402350
# 2024-10-30   -0.159100
# 2024-10-31    0.000000
# 2024-11-01   -0.318200
# 2024-11-02    0.000000
# 2024-11-03    0.041700
# 2024-11-04    0.051517
# 2024-11-05    0.000000
# 2024-11-06    0.239291
# 2024-11-07    0.281840
# 2024-11-08    0.134612
# 2024-11-09    0.318450
# 2024-11-10    0.000000
# 2024-11-11    0.286267
# 2024-11-12    0.012950
# 2024-11-13    0.413850
# 2024-11-14   -0.476700
# 2024-11-15    0.619367
# 2024-11-16    0.331650
# 2024-11-17    0.202300
# 2024-11-18    0.197650
# 2024-11-19   -0.086133
# 2024-11-20    0.284200
# 2024-11-21   -0.335250
# 2024-11-22    0.363450
# 2024-11-23    0.000000
# 2024-11-24    0.381800
# 2024-11-25   -0.108460
# 2024-11-26   -0.462667
# 2024-11-27   -0.401900
# 2024-11-28    0.000000
# Freq: D, Name: sentiment, dtype: float64
# /tmp/ipykernel_12659/1208510680.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sentiment'].fillna(0, inplace=True)
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 96s 96s/step - loss: 0.4511 - mae: 0.6183 - val_loss: 0.4304 - val_mae: 0.6514
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 0.3140 - mae: 0.5039 - val_loss: 0.2384 - val_mae: 0.4826
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.1957 - mae: 0.4011 - val_loss: 0.0675 - val_mae: 0.2506
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - loss: 0.0816 - mae: 0.2420 - val_loss: 0.0091 - val_mae: 0.0740
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 0.0423 - mae: 0.1634 - val_loss: 0.1163 - val_mae: 0.3368
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.1049 - mae: 0.2635 - val_loss: 0.0991 - val_mae: 0.3102
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - loss: 0.1074 - mae: 0.2657 - val_loss: 0.0266 - val_mae: 0.1520
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.0561 - mae: 0.1907 - val_loss: 0.0043 - val_mae: 0.0644
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.0418 - mae: 0.1463 - val_loss: 0.0246 - val_mae: 0.1412
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0479 - mae: 0.1751 - val_loss: 0.0540 - val_mae: 0.2215
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0554 - mae: 0.2062 - val_loss: 0.0708 - val_mae: 0.2564
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0703 - mae: 0.2262 - val_loss: 0.0704 - val_mae: 0.2556
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.0665 - mae: 0.2269 - val_loss: 0.0562 - val_mae: 0.2263
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 0.0581 - mae: 0.2049 - val_loss: 0.0350 - val_mae: 0.1740
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.0471 - mae: 0.1847 - val_loss: 0.0160 - val_mae: 0.1072
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0362 - mae: 0.1412 - val_loss: 0.0056 - val_mae: 0.0647
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 0.0395 - mae: 0.1498 - val_loss: 0.0041 - val_mae: 0.0630
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0454 - mae: 0.1664 - val_loss: 0.0055 - val_mae: 0.0620
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.0461 - mae: 0.1723 - val_loss: 0.0049 - val_mae: 0.0621
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0385 - mae: 0.1609 - val_loss: 0.0039 - val_mae: 0.0621
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.0435 - mae: 0.1598 - val_loss: 0.0079 - val_mae: 0.0637
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.0326 - mae: 0.1308 - val_loss: 0.0192 - val_mae: 0.1223
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 0.0324 - mae: 0.1389 - val_loss: 0.0317 - val_mae: 0.1651
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 0.0325 - mae: 0.1426 - val_loss: 0.0390 - val_mae: 0.1859
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.0357 - mae: 0.1569 - val_loss: 0.0385 - val_mae: 0.1845
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0364 - mae: 0.1479 - val_loss: 0.0330 - val_mae: 0.1691
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0386 - mae: 0.1478 - val_loss: 0.0245 - val_mae: 0.1421
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0338 - mae: 0.1372 - val_loss: 0.0163 - val_mae: 0.1101
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.0311 - mae: 0.1207 - val_loss: 0.0115 - val_mae: 0.0849
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0295 - mae: 0.1255 - val_loss: 0.0094 - val_mae: 0.0722
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# 2024-10-29    0.402350
# 2024-10-30   -0.159100
# 2024-10-31    0.000000
# 2024-11-01   -0.318200
# 2024-11-02    0.000000
# 2024-11-03    0.041700
# 2024-11-04    0.051517
# 2024-11-05    0.000000
# 2024-11-06    0.239291
# 2024-11-07    0.281840
# 2024-11-08    0.134612
# 2024-11-09    0.318450
# 2024-11-10    0.000000
# 2024-11-11    0.286267
# 2024-11-12    0.012950
# 2024-11-13    0.413850
# 2024-11-14   -0.476700
# 2024-11-15    0.619367
# 2024-11-16    0.331650
# 2024-11-17    0.202300
# 2024-11-18    0.197650
# 2024-11-19   -0.086133
# 2024-11-20    0.284200
# 2024-11-21   -0.335250
# 2024-11-22    0.363450
# 2024-11-23    0.000000
# 2024-11-24    0.381800
# 2024-11-25   -0.108460
# 2024-11-26   -0.462667
# 2024-11-27   -0.401900
# 2024-11-28    0.000000
# Freq: D, Name: sentiment, dtype: float64
# /tmp/ipykernel_12659/1208510680.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sentiment'].fillna(0, inplace=True)
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 42s 42s/step - loss: 0.3943 - mae: 0.6110 - val_loss: 0.5671 - val_mae: 0.7527
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2483 - mae: 0.4835 - val_loss: 0.2928 - val_mae: 0.5409
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1115 - mae: 0.3218 - val_loss: 0.0609 - val_mae: 0.2468
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0089 - mae: 0.0901 - val_loss: 0.0191 - val_mae: 0.1374
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0410 - mae: 0.1990 - val_loss: 0.0574 - val_mae: 0.2389
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0833 - mae: 0.2792 - val_loss: 0.0111 - val_mae: 0.1048
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0318 - mae: 0.1732 - val_loss: 0.0050 - val_mae: 0.0708
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0028 - mae: 0.0463 - val_loss: 0.0490 - val_mae: 0.2213
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0036 - mae: 0.0506 - val_loss: 0.1047 - val_mae: 0.3234
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0317 - mae: 0.1683 - val_loss: 0.1319 - val_mae: 0.3630
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0354 - mae: 0.1791 - val_loss: 0.1273 - val_mae: 0.3567
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0361 - mae: 0.1788 - val_loss: 0.0990 - val_mae: 0.3145
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0241 - mae: 0.1484 - val_loss: 0.0600 - val_mae: 0.2448
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0153 - mae: 0.1125 - val_loss: 0.0231 - val_mae: 0.1521
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 8.1448e-04 - mae: 0.0178 - val_loss: 0.0037 - val_mae: 0.0606
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0031 - mae: 0.0491 - val_loss: 7.9355e-05 - val_mae: 0.0086
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0115 - mae: 0.1023 - val_loss: 0.0013 - val_mae: 0.0365
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0188 - mae: 0.1321 - val_loss: 2.9385e-04 - val_mae: 0.0170
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0123 - mae: 0.1060 - val_loss: 9.8411e-04 - val_mae: 0.0314
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0038 - mae: 0.0527 - val_loss: 0.0072 - val_mae: 0.0847
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0014 - mae: 0.0321 - val_loss: 0.0180 - val_mae: 0.1343
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0040 - mae: 0.0453 - val_loss: 0.0293 - val_mae: 0.1712
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0031 - mae: 0.0440 - val_loss: 0.0375 - val_mae: 0.1937
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0055 - mae: 0.0674 - val_loss: 0.0400 - val_mae: 0.2000
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0055 - mae: 0.0618 - val_loss: 0.0372 - val_mae: 0.1927
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0062 - mae: 0.0720 - val_loss: 0.0297 - val_mae: 0.1723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# [*********************100%***********************]  1 of 1 completed
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Processing AAPL...
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 22s 22s/step - loss: 0.0816 - mae: 0.2460 - val_loss: 0.0758 - val_mae: 0.2490
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0513 - mae: 0.1773 - val_loss: 0.0298 - val_mae: 0.1246
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0307 - mae: 0.1444 - val_loss: 0.0155 - val_mae: 0.1223
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0395 - mae: 0.1853 - val_loss: 0.0161 - val_mae: 0.1217
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0390 - mae: 0.1849 - val_loss: 0.0147 - val_mae: 0.1199
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0323 - mae: 0.1720 - val_loss: 0.0200 - val_mae: 0.1187
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0273 - mae: 0.1451 - val_loss: 0.0278 - val_mae: 0.1183
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0273 - mae: 0.1354 - val_loss: 0.0326 - val_mae: 0.1373
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0262 - mae: 0.1281 - val_loss: 0.0325 - val_mae: 0.1372
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0278 - mae: 0.1283 - val_loss: 0.0282 - val_mae: 0.1208
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0265 - mae: 0.1358 - val_loss: 0.0228 - val_mae: 0.1170
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0242 - mae: 0.1336 - val_loss: 0.0180 - val_mae: 0.1173
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0219 - mae: 0.1317 - val_loss: 0.0151 - val_mae: 0.1176
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0209 - mae: 0.1367 - val_loss: 0.0141 - val_mae: 0.1178
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0227 - mae: 0.1449 - val_loss: 0.0139 - val_mae: 0.1177
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0252 - mae: 0.1520 - val_loss: 0.0144 - val_mae: 0.1174
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0237 - mae: 0.1469 - val_loss: 0.0166 - val_mae: 0.1169
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0191 - mae: 0.1297 - val_loss: 0.0204 - val_mae: 0.1163
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0219 - mae: 0.1284 - val_loss: 0.0241 - val_mae: 0.1160
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0198 - mae: 0.1157 - val_loss: 0.0258 - val_mae: 0.1158
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0206 - mae: 0.1176 - val_loss: 0.0252 - val_mae: 0.1157
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0197 - mae: 0.1161 - val_loss: 0.0233 - val_mae: 0.1157
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0195 - mae: 0.1201 - val_loss: 0.0207 - val_mae: 0.1158
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0178 - mae: 0.1163 - val_loss: 0.0184 - val_mae: 0.1162
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0165 - mae: 0.1118 - val_loss: 0.0166 - val_mae: 0.1162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 47s 47s/step - loss: 0.0051 - mae: 0.0504 - val_loss: 0.0405 - val_mae: 0.1996
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.0032 - mae: 0.0426 - val_loss: 0.0291 - val_mae: 0.1690
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0030 - mae: 0.0496 - val_loss: 0.0286 - val_mae: 0.1672
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0028 - mae: 0.0471 - val_loss: 0.0326 - val_mae: 0.1785
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0024 - mae: 0.0394 - val_loss: 0.0367 - val_mae: 0.1895
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0022 - mae: 0.0349 - val_loss: 0.0378 - val_mae: 0.1920
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0020 - mae: 0.0348 - val_loss: 0.0349 - val_mae: 0.1839
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0021 - mae: 0.0376 - val_loss: 0.0298 - val_mae: 0.1693
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0020 - mae: 0.0373 - val_loss: 0.0264 - val_mae: 0.1590
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0019 - mae: 0.0377 - val_loss: 0.0264 - val_mae: 0.1588
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0015 - mae: 0.0320 - val_loss: 0.0288 - val_mae: 0.1661
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0016 - mae: 0.0341 - val_loss: 0.0321 - val_mae: 0.1759
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0016 - mae: 0.0344 - val_loss: 0.0335 - val_mae: 0.1801
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0016 - mae: 0.0320 - val_loss: 0.0321 - val_mae: 0.1762
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0015 - mae: 0.0320 - val_loss: 0.0292 - val_mae: 0.1673
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0013 - mae: 0.0299 - val_loss: 0.0253 - val_mae: 0.1549
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0014 - mae: 0.0306 - val_loss: 0.0236 - val_mae: 0.1487
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 9.1654e-04 - mae: 0.0250 - val_loss: 0.0233 - val_mae: 0.1475
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 8.5167e-04 - mae: 0.0255 - val_loss: 0.0258 - val_mae: 0.1555
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 7.2694e-04 - mae: 0.0247 - val_loss: 0.0281 - val_mae: 0.1626
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 9.0202e-04 - mae: 0.0249 - val_loss: 0.0267 - val_mae: 0.1581
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 8.2407e-04 - mae: 0.0247 - val_loss: 0.0229 - val_mae: 0.1454
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 5.2856e-04 - mae: 0.0176 - val_loss: 0.0183 - val_mae: 0.1281
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 4.3130e-04 - mae: 0.0183 - val_loss: 0.0170 - val_mae: 0.1230
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 5.6081e-04 - mae: 0.0197 - val_loss: 0.0204 - val_mae: 0.1360
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 4.6382e-04 - mae: 0.0134 - val_loss: 0.0195 - val_mae: 0.1321
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.3181e-04 - mae: 0.0100 - val_loss: 0.0153 - val_mae: 0.1151
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.5536e-04 - mae: 0.0119 - val_loss: 0.0141 - val_mae: 0.1093
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1.5024e-04 - mae: 0.0098 - val_loss: 0.0137 - val_mae: 0.1070
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 4.8559e-04 - mae: 0.0190 - val_loss: 0.0196 - val_mae: 0.1324
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 5.4004e-04 - mae: 0.0180 - val_loss: 0.0135 - val_mae: 0.1069
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.1300e-04 - mae: 0.0121 - val_loss: 0.0073 - val_mae: 0.0731
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 4.8481e-04 - mae: 0.0180 - val_loss: 0.0083 - val_mae: 0.0797
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.4208e-04 - mae: 0.0100 - val_loss: 0.0118 - val_mae: 0.1000
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.6746e-04 - mae: 0.0109 - val_loss: 0.0116 - val_mae: 0.0993
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 2.4363e-04 - mae: 0.0140 - val_loss: 0.0068 - val_mae: 0.0718
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 1.0894e-04 - mae: 0.0091 - val_loss: 0.0045 - val_mae: 0.0539
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.2928e-04 - mae: 0.0091 - val_loss: 0.0042 - val_mae: 0.0512
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.3918e-04 - mae: 0.0088 - val_loss: 0.0057 - val_mae: 0.0655
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 5.4804e-05 - mae: 0.0065 - val_loss: 0.0077 - val_mae: 0.0794
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.6815e-05 - mae: 0.0078 - val_loss: 0.0072 - val_mae: 0.0773
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 2.1052e-04 - mae: 0.0112 - val_loss: 0.0042 - val_mae: 0.0552
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 4.2675e-05 - mae: 0.0053 - val_loss: 0.0026 - val_mae: 0.0389
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.9330e-04 - mae: 0.0130 - val_loss: 0.0038 - val_mae: 0.0521
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 5.0026e-05 - mae: 0.0047 - val_loss: 0.0051 - val_mae: 0.0640
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 7.8108e-05 - mae: 0.0076 - val_loss: 0.0053 - val_mae: 0.0660
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.2773e-04 - mae: 0.0099 - val_loss: 0.0036 - val_mae: 0.0518
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.0176e-04 - mae: 0.0074 - val_loss: 0.0014 - val_mae: 0.0290
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 3.9795e-04 - mae: 0.0175 - val_loss: 0.0022 - val_mae: 0.0377
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 7.0629e-05 - mae: 0.0054 - val_loss: 0.0048 - val_mae: 0.0633
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.5280e-04 - mae: 0.0120 - val_loss: 0.0045 - val_mae: 0.0617
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.0711e-04 - mae: 0.0079 - val_loss: 0.0026 - val_mae: 0.0430
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 4.0039e-05 - mae: 0.0058 - val_loss: 0.0013 - val_mae: 0.0260
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.3610e-04 - mae: 0.0094 - val_loss: 0.0013 - val_mae: 0.0258
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.4580e-04 - mae: 0.0113 - val_loss: 0.0026 - val_mae: 0.0439
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 6.7299e-05 - mae: 0.0070 - val_loss: 0.0036 - val_mae: 0.0541
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.3613e-04 - mae: 0.0091 - val_loss: 0.0027 - val_mae: 0.0443
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.0874e-04 - mae: 0.0077 - val_loss: 0.0013 - val_mae: 0.0261
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.3454e-04 - mae: 0.0081 - val_loss: 8.3445e-04 - val_mae: 0.0256
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 9.4723e-05 - mae: 0.0072 - val_loss: 8.1155e-04 - val_mae: 0.0250
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.7427e-04 - mae: 0.0097 - val_loss: 0.0015 - val_mae: 0.0294
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.3377e-04 - mae: 0.0087 - val_loss: 0.0025 - val_mae: 0.0429
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.8286e-04 - mae: 0.0122 - val_loss: 0.0022 - val_mae: 0.0390
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 5.9735e-05 - mae: 0.0064 - val_loss: 0.0014 - val_mae: 0.0274
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 8.7180e-05 - mae: 0.0071 - val_loss: 0.0010 - val_mae: 0.0254
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 7.4387e-05 - mae: 0.0058 - val_loss: 7.3190e-04 - val_mae: 0.0251
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 5.4089e-05 - mae: 0.0055 - val_loss: 7.5562e-04 - val_mae: 0.0246
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 2.5581e-04 - mae: 0.0120 - val_loss: 0.0016 - val_mae: 0.0325
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.1256e-04 - mae: 0.0078 - val_loss: 0.0021 - val_mae: 0.0389
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 7.3903e-05 - mae: 0.0061 - val_loss: 0.0020 - val_mae: 0.0380
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 6.4178e-05 - mae: 0.0063 - val_loss: 0.0014 - val_mae: 0.0291
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 6.7879e-05 - mae: 0.0065 - val_loss: 0.0012 - val_mae: 0.0261
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 5.2315e-05 - mae: 0.0064 - val_loss: 0.0010 - val_mae: 0.0228
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 5.4599e-05 - mae: 0.0056 - val_loss: 0.0011 - val_mae: 0.0250
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 5.5115e-05 - mae: 0.0060 - val_loss: 0.0011 - val_mae: 0.0242
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 4.0693e-05 - mae: 0.0050 - val_loss: 7.6891e-04 - val_mae: 0.0219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 935ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 2024-10-29    0.132663
# 2024-10-30    0.476700
# 2024-10-31    0.085100
# 2024-11-01   -0.099700
# 2024-11-02   -0.055633
# 2024-11-03    0.000000
# 2024-11-04    0.000000
# 2024-11-05    0.040460
# 2024-11-06    0.286500
# 2024-11-07    0.000000
# 2024-11-08    0.000000
# 2024-11-09    0.000000
# 2024-11-10    0.000000
# 2024-11-11    0.164925
# 2024-11-12    0.202300
# 2024-11-13    0.192933
# 2024-11-14    0.297725
# 2024-11-15    0.099767
# 2024-11-16    0.000000
# 2024-11-17    0.000000
# 2024-11-18    0.222100
# 2024-11-19   -0.016560
# 2024-11-20    0.194614
# 2024-11-21    0.015440
# 2024-11-22    0.340000
# 2024-11-23    0.000000
# 2024-11-24    0.000000
# 2024-11-25    0.074367
# 2024-11-26    0.000000
# 2024-11-27    0.056360
# 2024-11-28    0.000000
# Freq: D, Name: sentiment, dtype: float64
# /tmp/ipykernel_12659/1208510680.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sentiment'].fillna(0, inplace=True)
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 212s 212s/step - loss: 0.0831 - mae: 0.2512 - val_loss: 0.0679 - val_mae: 0.2334
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.0487 - mae: 0.1707 - val_loss: 0.0202 - val_mae: 0.1141
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0254 - mae: 0.1259 - val_loss: 0.0223 - val_mae: 0.1127
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0291 - mae: 0.1586 - val_loss: 0.0342 - val_mae: 0.1456
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.0356 - mae: 0.1604 - val_loss: 0.0197 - val_mae: 0.1164
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0237 - mae: 0.1471 - val_loss: 0.0143 - val_mae: 0.1187
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0192 - mae: 0.1258 - val_loss: 0.0214 - val_mae: 0.1200
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - loss: 0.0210 - mae: 0.1144 - val_loss: 0.0276 - val_mae: 0.1212
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - loss: 0.0238 - mae: 0.1140 - val_loss: 0.0273 - val_mae: 0.1227
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0206 - mae: 0.1055 - val_loss: 0.0223 - val_mae: 0.1243
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0194 - mae: 0.1081 - val_loss: 0.0173 - val_mae: 0.1262
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0152 - mae: 0.1047 - val_loss: 0.0168 - val_mae: 0.1282
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.0147 - mae: 0.1168 - val_loss: 0.0215 - val_mae: 0.1308
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0130 - mae: 0.1090 - val_loss: 0.0262 - val_mae: 0.1336
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0175 - mae: 0.1258 - val_loss: 0.0254 - val_mae: 0.1361
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0115 - mae: 0.1019 - val_loss: 0.0221 - val_mae: 0.1384
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# 2024-10-29    0.132663
# 2024-10-30    0.476700
# 2024-10-31    0.085100
# 2024-11-01   -0.099700
# 2024-11-02   -0.055633
# 2024-11-03    0.000000
# 2024-11-04    0.000000
# 2024-11-05    0.040460
# 2024-11-06    0.286500
# 2024-11-07    0.000000
# 2024-11-08    0.000000
# 2024-11-09    0.000000
# 2024-11-10    0.000000
# 2024-11-11    0.164925
# 2024-11-12    0.202300
# 2024-11-13    0.192933
# 2024-11-14    0.297725
# 2024-11-15    0.099767
# 2024-11-16    0.000000
# 2024-11-17    0.000000
# 2024-11-18    0.222100
# 2024-11-19   -0.016560
# 2024-11-20    0.194614
# 2024-11-21    0.015440
# 2024-11-22    0.340000
# 2024-11-23    0.000000
# 2024-11-24    0.000000
# 2024-11-25    0.074367
# 2024-11-26    0.000000
# 2024-11-27    0.056360
# 2024-11-28    0.000000
# Freq: D, Name: sentiment, dtype: float64
# /tmp/ipykernel_12659/1208510680.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sentiment'].fillna(0, inplace=True)
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 45s 45s/step - loss: 0.0049 - mae: 0.0464 - val_loss: 0.0093 - val_mae: 0.0940
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0067 - mae: 0.0759 - val_loss: 0.0259 - val_mae: 0.1588
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.0023 - mae: 0.0375 - val_loss: 0.0379 - val_mae: 0.1927
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - loss: 0.0026 - mae: 0.0370 - val_loss: 0.0379 - val_mae: 0.1926
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0023 - mae: 0.0338 - val_loss: 0.0296 - val_mae: 0.1697
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0015 - mae: 0.0292 - val_loss: 0.0187 - val_mae: 0.1338
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0020 - mae: 0.0365 - val_loss: 0.0121 - val_mae: 0.1064
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0026 - mae: 0.0421 - val_loss: 0.0129 - val_mae: 0.1099
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.0023 - mae: 0.0394 - val_loss: 0.0182 - val_mae: 0.1315
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0016 - mae: 0.0354 - val_loss: 0.0258 - val_mae: 0.1576
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0018 - mae: 0.0343 - val_loss: 0.0300 - val_mae: 0.1704
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# [*********************100%***********************]  1 of 1 completed
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Processing NVDA...
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 41s 41s/step - loss: 0.7084 - mae: 0.8258 - val_loss: 0.1456 - val_mae: 0.3779
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 0.5537 - mae: 0.7284 - val_loss: 0.0331 - val_mae: 0.1758
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - loss: 0.3630 - mae: 0.5846 - val_loss: 0.0143 - val_mae: 0.1136
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.1753 - mae: 0.3705 - val_loss: 0.2811 - val_mae: 0.5297
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0752 - mae: 0.2220 - val_loss: 0.8890 - val_mae: 0.9428
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1995 - mae: 0.3758 - val_loss: 0.8680 - val_mae: 0.9316
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.2030 - mae: 0.3876 - val_loss: 0.5285 - val_mae: 0.7268
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1080 - mae: 0.2875 - val_loss: 0.2591 - val_mae: 0.5084
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0643 - mae: 0.2080 - val_loss: 0.1170 - val_mae: 0.3407
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0776 - mae: 0.2038 - val_loss: 0.0569 - val_mae: 0.2360
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.1066 - mae: 0.2492 - val_loss: 0.0364 - val_mae: 0.1872
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1175 - mae: 0.2930 - val_loss: 0.0359 - val_mae: 0.1859
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.1059 - mae: 0.2708 - val_loss: 0.0495 - val_mae: 0.2196
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 21s 21s/step
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 40s 40s/step - loss: 0.8210 - mae: 0.8981 - val_loss: 0.6814 - val_mae: 0.8254
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.5791 - mae: 0.7571 - val_loss: 0.3758 - val_mae: 0.6130
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.3757 - mae: 0.6116 - val_loss: 0.0849 - val_mae: 0.2912
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.1491 - mae: 0.3854 - val_loss: 0.0353 - val_mae: 0.1873
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0270 - mae: 0.1470 - val_loss: 0.5476 - val_mae: 0.7398
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.1748 - mae: 0.3474 - val_loss: 0.5532 - val_mae: 0.7435
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1567 - mae: 0.3437 - val_loss: 0.2597 - val_mae: 0.5093
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0722 - mae: 0.2182 - val_loss: 0.0587 - val_mae: 0.2419
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0195 - mae: 0.1228 - val_loss: 0.0012 - val_mae: 0.0319
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0292 - mae: 0.1513 - val_loss: 0.0101 - val_mae: 0.0999
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0641 - mae: 0.2447 - val_loss: 0.0250 - val_mae: 0.1578
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0857 - mae: 0.2864 - val_loss: 0.0245 - val_mae: 0.1563
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0791 - mae: 0.2761 - val_loss: 0.0122 - val_mae: 0.1100
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0546 - mae: 0.2238 - val_loss: 0.0011 - val_mae: 0.0315
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0357 - mae: 0.1768 - val_loss: 0.0053 - val_mae: 0.0716
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.0141 - mae: 0.1050 - val_loss: 0.0360 - val_mae: 0.1894
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0112 - mae: 0.0970 - val_loss: 0.0910 - val_mae: 0.3013
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0156 - mae: 0.1035 - val_loss: 0.1446 - val_mae: 0.3800
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0404 - mae: 0.1588 - val_loss: 0.1586 - val_mae: 0.3980
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0361 - mae: 0.1537 - val_loss: 0.1316 - val_mae: 0.3626
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0442 - mae: 0.1686 - val_loss: 0.0800 - val_mae: 0.2826
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0202 - mae: 0.1173 - val_loss: 0.0371 - val_mae: 0.1922
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.0094 - mae: 0.0724 - val_loss: 0.0119 - val_mae: 0.1085
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0070 - mae: 0.0673 - val_loss: 0.0018 - val_mae: 0.0407
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 2024-10-29    0.089300
# 2024-10-30    0.000000
# 2024-10-31    0.279750
# 2024-11-01   -0.112000
# 2024-11-02    0.000000
# 2024-11-03    0.000000
# 2024-11-04    0.171733
# 2024-11-05    0.190960
# 2024-11-06    0.592650
# 2024-11-07    0.915300
# 2024-11-08    0.000000
# 2024-11-09    0.000000
# 2024-11-10    0.431700
# 2024-11-11    0.113333
# 2024-11-12    0.112050
# 2024-11-13    0.018100
# 2024-11-14    0.624000
# 2024-11-15    0.437850
# 2024-11-16    0.458550
# 2024-11-17    0.000000
# 2024-11-18   -0.091486
# 2024-11-19    0.044450
# 2024-11-20    0.393586
# 2024-11-21    0.127613
# 2024-11-22    0.041833
# 2024-11-23    0.401900
# 2024-11-24    0.534000
# 2024-11-25    0.317050
# 2024-11-26   -0.257550
# 2024-11-27    0.069725
# 2024-11-28    0.000000
# Freq: D, Name: sentiment, dtype: float64
# /tmp/ipykernel_12659/1208510680.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sentiment'].fillna(0, inplace=True)
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 31s 31s/step - loss: 0.6768 - mae: 0.8069 - val_loss: 0.0774 - val_mae: 0.2728
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.4355 - mae: 0.6443 - val_loss: 0.0030 - val_mae: 0.0544
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.1828 - mae: 0.3947 - val_loss: 0.1523 - val_mae: 0.3865
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0534 - mae: 0.1796 - val_loss: 0.6841 - val_mae: 0.8253
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.1747 - mae: 0.3719 - val_loss: 0.6507 - val_mae: 0.8046
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.1590 - mae: 0.3413 - val_loss: 0.3686 - val_mae: 0.6041
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 0.0947 - mae: 0.2704 - val_loss: 0.1475 - val_mae: 0.3790
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0405 - mae: 0.1558 - val_loss: 0.0498 - val_mae: 0.2136
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.0571 - mae: 0.1887 - val_loss: 0.0208 - val_mae: 0.1283
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.0862 - mae: 0.2546 - val_loss: 0.0162 - val_mae: 0.1080
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0896 - mae: 0.2580 - val_loss: 0.0223 - val_mae: 0.1323
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0794 - mae: 0.2325 - val_loss: 0.0416 - val_mae: 0.1912
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# 2024-10-29    0.089300
# 2024-10-30    0.000000
# 2024-10-31    0.279750
# 2024-11-01   -0.112000
# 2024-11-02    0.000000
# 2024-11-03    0.000000
# 2024-11-04    0.171733
# 2024-11-05    0.190960
# 2024-11-06    0.592650
# 2024-11-07    0.915300
# 2024-11-08    0.000000
# 2024-11-09    0.000000
# 2024-11-10    0.431700
# 2024-11-11    0.113333
# 2024-11-12    0.112050
# 2024-11-13    0.018100
# 2024-11-14    0.624000
# 2024-11-15    0.437850
# 2024-11-16    0.458550
# 2024-11-17    0.000000
# 2024-11-18   -0.091486
# 2024-11-19    0.044450
# 2024-11-20    0.393586
# 2024-11-21    0.127613
# 2024-11-22    0.041833
# 2024-11-23    0.401900
# 2024-11-24    0.534000
# 2024-11-25    0.317050
# 2024-11-26   -0.257550
# 2024-11-27    0.069725
# 2024-11-28    0.000000
# Freq: D, Name: sentiment, dtype: float64
# /tmp/ipykernel_12659/1208510680.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sentiment'].fillna(0, inplace=True)
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step - loss: 0.8249 - mae: 0.8999 - val_loss: 0.7238 - val_mae: 0.8507
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.6044 - mae: 0.7725 - val_loss: 0.4100 - val_mae: 0.6401
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.3773 - mae: 0.6123 - val_loss: 0.1168 - val_mae: 0.3410
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1393 - mae: 0.3726 - val_loss: 0.0075 - val_mae: 0.0801
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0117 - mae: 0.0852 - val_loss: 0.2970 - val_mae: 0.5432
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1707 - mae: 0.3624 - val_loss: 0.3006 - val_mae: 0.5464
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1533 - mae: 0.3516 - val_loss: 0.1229 - val_mae: 0.3482
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0537 - mae: 0.1863 - val_loss: 0.0154 - val_mae: 0.1194
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0104 - mae: 0.0867 - val_loss: 0.0045 - val_mae: 0.0607
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0244 - mae: 0.1412 - val_loss: 0.0308 - val_mae: 0.1734
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0477 - mae: 0.2101 - val_loss: 0.0518 - val_mae: 0.2263
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0742 - mae: 0.2702 - val_loss: 0.0519 - val_mae: 0.2263
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0661 - mae: 0.2555 - val_loss: 0.0354 - val_mae: 0.1863
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0444 - mae: 0.2067 - val_loss: 0.0147 - val_mae: 0.1177
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0279 - mae: 0.1639 - val_loss: 0.0016 - val_mae: 0.0306
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0091 - mae: 0.0833 - val_loss: 0.0065 - val_mae: 0.0736
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0056 - mae: 0.0638 - val_loss: 0.0273 - val_mae: 0.1613
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 0.0207 - mae: 0.1237 - val_loss: 0.0464 - val_mae: 0.2123
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0230 - mae: 0.1301 - val_loss: 0.0520 - val_mae: 0.2250
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0244 - mae: 0.1364 - val_loss: 0.0405 - val_mae: 0.1981
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0239 - mae: 0.1307 - val_loss: 0.0211 - val_mae: 0.1410
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0055 - mae: 0.0639 - val_loss: 0.0080 - val_mae: 0.0830
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0032 - mae: 0.0489 - val_loss: 0.0021 - val_mae: 0.0330
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0041 - mae: 0.0479 - val_loss: 0.0010 - val_mae: 0.0310
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0077 - mae: 0.0776 - val_loss: 0.0025 - val_mae: 0.0403
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0083 - mae: 0.0833 - val_loss: 0.0039 - val_mae: 0.0553
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0098 - mae: 0.0868 - val_loss: 0.0040 - val_mae: 0.0560
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0075 - mae: 0.0731 - val_loss: 0.0030 - val_mae: 0.0463
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0111 - mae: 0.0890 - val_loss: 0.0015 - val_mae: 0.0306
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0039 - mae: 0.0515 - val_loss: 9.8530e-04 - val_mae: 0.0313
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0032 - mae: 0.0460 - val_loss: 0.0021 - val_mae: 0.0328
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0081 - mae: 0.0801 - val_loss: 0.0040 - val_mae: 0.0545
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0044 - mae: 0.0599 - val_loss: 0.0060 - val_mae: 0.0699
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0058 - mae: 0.0640 - val_loss: 0.0062 - val_mae: 0.0717
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0056 - mae: 0.0627 - val_loss: 0.0050 - val_mae: 0.0624
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0078 - mae: 0.0782 - val_loss: 0.0026 - val_mae: 0.0400
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0032 - mae: 0.0515 - val_loss: 0.0013 - val_mae: 0.0317
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0024 - mae: 0.0435 - val_loss: 9.8679e-04 - val_mae: 0.0312
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0029 - mae: 0.0480 - val_loss: 0.0013 - val_mae: 0.0308
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0026 - mae: 0.0436 - val_loss: 0.0019 - val_mae: 0.0305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# [*********************100%***********************]  1 of 1 completed
# Processing GOOG...
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 65s 65s/step - loss: 0.6053 - mae: 0.7487 - val_loss: 0.0946 - val_mae: 0.2923
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.3895 - mae: 0.5899 - val_loss: 0.0119 - val_mae: 0.1066
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1872 - mae: 0.3846 - val_loss: 0.1477 - val_mae: 0.3644
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0673 - mae: 0.2320 - val_loss: 0.7268 - val_mae: 0.8406
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.1991 - mae: 0.3438 - val_loss: 0.6804 - val_mae: 0.8127
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1834 - mae: 0.3287 - val_loss: 0.3808 - val_mae: 0.6025
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0833 - mae: 0.2150 - val_loss: 0.1706 - val_mae: 0.3937
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0620 - mae: 0.2189 - val_loss: 0.0733 - val_mae: 0.2434
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0761 - mae: 0.2459 - val_loss: 0.0374 - val_mae: 0.1553
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0933 - mae: 0.2622 - val_loss: 0.0282 - val_mae: 0.1234
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1051 - mae: 0.2848 - val_loss: 0.0312 - val_mae: 0.1346
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1079 - mae: 0.2894 - val_loss: 0.0455 - val_mae: 0.1790
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 841ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 820ms/step
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
