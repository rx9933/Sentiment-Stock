# %% [markdown]
# # Notes:
# has sentiment analysis (at bottom)
#
# 1 day predictions with all previous data
#
# erraneous due to small data size

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pywt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional, Flatten, RepeatVector
from tensorflow.keras.callbacks import EarlyStopping
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import requests,os
from datetime import datetime, timedelta
# Helper Function to fetch historical stock data
import yfinance as yf
def get_stock_data(ticker, start_date, end_date):
    try:
        # https://medium.com/nerd-for-tech/all-you-need-to-know-about-yfinance-yahoo-finance-library-fa4c6e48f08e
        #data = yf.Ticker(ticker).history(start=start_date, end=end_date)  
        data = yf.download(ticker, start=start_date, end=end_date)
        return data
    except Exception as e:
        return f"Error fetching data: {e}"
    
    
# Sentiment 
def fetch_news_and_sentiment(ticker, start_date, end_date):
    api_url = f"https://newsapi.org/v2/everything?q={ticker}&from={start_date}&to={end_date}&apiKey=7e9676fa277d423f8deff9a4894bd717"
    response = requests.get(api_url)
    news_data = response.json()

    headlines = []
    dates = []
    if "articles" in news_data:
        for article in news_data['articles']:
            headlines.append(article['title'])
            # Extract the publication date of the article
            dates.append(article['publishedAt'][:10])  # Extract the YYYY-MM-DD format

    # Perform sentiment analysis using VADER
    analyzer = SentimentIntensityAnalyzer()
    sentiment_data = []
    for headline, date in zip(headlines, dates):
        score = analyzer.polarity_scores(headline)
        sentiment_data.append({'date': date, 'sentiment': score['compound']})  # Store date and compound score

    return sentiment_data

# Function to aggregate daily sentiment scores
def aggregate_daily_sentiment(sentiment_data, start_date, end_date):
    # Convert to DataFrame
    sentiment_df = pd.DataFrame(sentiment_data)
    # print(sentiment_df[:30])
    sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])

    # Group by date and calculate the average sentiment for each day
    daily_sentiment = (
        sentiment_df.groupby('date')['sentiment']
        .mean()
        .reindex(pd.date_range(start_date, end_date), fill_value=0)  # Fill missing days with 0 sentiment
    )
    print(daily_sentiment)
    return daily_sentiment
# Data Preprocessing Function
def preprocess_data(df, ticker, start_date, end_date, wavelet_transform=False, sentiment=False, seq_length=5):
    # Normalize Close prices
    scaler_close = MinMaxScaler(feature_range=(0, 1))
    df['Close_scaled'] = scaler_close.fit_transform(df['Close'].values.reshape(-1, 1))

    # Optionally apply Wavelet Transform to Close prices
    if wavelet_transform:
        wavelet = pywt.Wavelet('db6')
        def wavelet_transform(data, lvl=8):
            coeff = pywt.wavedec(data, wavelet, mode='symmetric', level=lvl)
            return coeff
        def inverse_wavelet_transform(coeff):
            for i in range(3):
                coeff[-(i + 1)] = np.zeros_like(coeff[-(i + 1)])
            return pywt.waverec(coeff, wavelet, mode='symmetric')
        
        close_prices = df['Close'].values
        wavelet_coeff = wavelet_transform(close_prices)
        reconstructed_close = inverse_wavelet_transform(wavelet_coeff)
        
        # Adjust the reconstructed data length to match the original DataFrame
        # reconstructed_close = np.pad(reconstructed_close, (0, len(df) - len(reconstructed_close)), mode='edge')
        reconstructed_close = np.pad(reconstructed_close, (0, max(0, len(df) - len(reconstructed_close))), mode='edge')

        df['Close_scaled'] = scaler_close.fit_transform(reconstructed_close.reshape(-1, 1))

    # Optionally include Sentiment data
    if sentiment:
        sentiment_data = fetch_news_and_sentiment(ticker, start_date, end_date)

        # Aggregate daily sentiment scores
        daily_sentiment_scores = aggregate_daily_sentiment(sentiment_data, start_date, end_date)

        df.index = pd.to_datetime(df.index)  # Convert stock_data index to datetime
        daily_sentiment_scores.index = pd.to_datetime(daily_sentiment_scores.index)  # Convert daily_sentiment index to datetime

        # Replace the "Sentiment" column in stock_data with values from daily_sentiment
        df['Sentiment'] = df.index.map(daily_sentiment_scores.get)

        # Fill any missing sentiment values with 0
        df['Sentiment'].fillna(0, inplace=True)

        scaler_sentiment = MinMaxScaler(feature_range=(0, 1))
        df['Sentiment_scaled'] = scaler_sentiment.fit_transform(df['Sentiment'].values.reshape(-1, 1))
        features = df[['Close_scaled', 'Sentiment_scaled']].values
    else:
        features = df[['Close_scaled']].values

    # Create sequences for LSTM
    X, y = [], []
    for i in range(len(features) - seq_length):
        X.append(features[i:i + seq_length])
        y.append(features[i + seq_length, 0])  # Target is the next Close value
    return np.array(X), np.array(y), scaler_close

# Build LSTM Model
# def build_lstm_model(input_shape, return_sequences=False):
#     model = Sequential([
#         Bidirectional(LSTM(units=256, return_sequences=True, input_shape=input_shape)),
#         Dropout(0.3),
#         Bidirectional(LSTM(units=128, return_sequences=return_sequences)),
#         Dropout(0.3),
#         RepeatVector(1),
#         Dense(units=64, activation='relu'),
#         Dense(units=32),
#         Flatten(),
#         Dense(units=1)
#     ])
#     model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
#     return model
def build_lstm_model(input_shape, return_sequences=False):
    model = Sequential([
        Bidirectional(LSTM(units=256, return_sequences=True, input_shape=input_shape)),
        Dropout(0.3),
        Bidirectional(LSTM(units=128, return_sequences=True)),  # Ensure return_sequences=True for repeat vector
        Dropout(0.3),
        Flatten(),  # Flatten the 3D output to 2D
        RepeatVector(1),
        Dense(units=64, activation='relu'),
        Dense(units=32),
        Flatten(),
        Dense(units=1)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    return model

# Train Model and Get Predictions
def train_and_predict(X_train, y_train, X_test, y_test, model, scaler_close):
    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Train the model
    model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping])

    # Make predictions
    train_predictions = model.predict(X_train)
    test_predictions = model.predict(X_test)

    # Inverse transform predictions and true values
    train_predictions = scaler_close.inverse_transform(train_predictions)
    test_predictions = scaler_close.inverse_transform(test_predictions)
    y_train = scaler_close.inverse_transform(y_train.reshape(-1, 1))
    y_test = scaler_close.inverse_transform(y_test.reshape(-1, 1))

    return train_predictions, test_predictions, y_train, y_test

# Calculate Metrics
def calculate_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    return mae, mse, rmse, r2

# Plot Results
def plot_results(df, seq_length, split, y_train, train_predictions, y_test, test_predictions, ticker, model_type):
    plt.figure(figsize=(14, 7))
    plt.plot(df.index[seq_length:split + seq_length], y_train, label='Train Actual', color='blue')
    plt.plot(df.index[seq_length:split + seq_length], train_predictions, label='Train Predicted', color='cyan')
    plt.plot(df.index[split + seq_length:], y_test, label='Test Actual', color='green')
    plt.plot(df.index[split + seq_length:], test_predictions, label='Test Predicted', color='red')
    plt.legend()
    plt.title(f"{ticker} - {model_type}: Predictions vs Actual")
    plt.xlabel("Time")
    plt.ylabel("Stock Price")
    directory = f"data/{ticker}/{model_type}"
    os.makedirs(directory, exist_ok=True)
    plt.savefig(directory)
    plt.show()


# Consolidated Function to Handle Multiple Tickers
def run_models_for_tickers(tickers, models=['LSTM', 'LSTM + Wavelet', 'LSTM + Sentiment', 'LSTM + Wavelet + Sentiment'], metrics=['MAE', 'MSE', 'RMSE', 'R2'], seq_length=5): # '
    results = []

    for ticker in tickers:
        start_date = "2024-10-29"
        end_date = "2024-11-28"
        df = get_stock_data(ticker,start_date,end_date)  # Assume a function to load stock data for each ticker
        print(f"Processing {ticker}...")
        
        for model_type in models:
            # Preprocess data based on model type
            wavelet_transform = 'Wavelet' in model_type
            sentiment = 'Sentiment' in model_type
            X, y, scaler_close = preprocess_data(df, ticker, start_date, end_date, wavelet_transform=wavelet_transform, sentiment=sentiment, seq_length=seq_length)
            
            # Split data into training and testing sets
            split = int(0.6 * len(X))
            X_train, X_test = X[:split], X[split:]
            y_train, y_test = y[:split], y[split:]

            # Build and train model
            model = build_lstm_model(input_shape=(seq_length, X.shape[2]), return_sequences=('Wavelet' in model_type))
            train_predictions, test_predictions, y_train, y_test = train_and_predict(X_train, y_train, X_test, y_test, model, scaler_close)
            
            y_train_true, y_test_true = df['Close'][5:split+5], df['Close'][split+5:]

            metrics_results = calculate_metrics(y_test_true, test_predictions)
            train_metrics_results = calculate_metrics(y_train_true, train_predictions)
            results.append({
                'Ticker': ticker,
                'Model': model_type,
                'Train MAE': train_metrics_results[0],
                'Train MSE': train_metrics_results[1],
                'Train RMSE': train_metrics_results[2],
                'Train R2': train_metrics_results[3],
                'Test MAE': metrics_results[0],
                'Test MSE': metrics_results[1],
                'Test RMSE': metrics_results[2],
                'Test R2': metrics_results[3]
            })

            # Plot results
            plot_results(df, seq_length, split, y_train_true, train_predictions, y_test_true, test_predictions, ticker, model_type)

    # Create DataFrame to store results
    results_df = pd.DataFrame(results)
    print(results_df)
tickers = ['TSLA', 'AAPL', 'NVDA', 'GOOG', 'AMZN', 'MSFT','INTC','BIPC']
models=['LSTM', 'CNN', 'RandomForest', 'XGBoost', 'LightGBM', 'LSTM+Wavelet', 'CNN+Wavelet', 'RandomForest+Wavelet', 'XGBoost+Wavelet', 'LightGBM+Wavelet']
# models=['LSTM + Sentiment + Wavelet']
# Example Usage
results_df = run_models_for_tickers(tickers, models, metrics=['MAE', 'MSE', 'RMSE', 'R2'])

# Example Usage
# run_models_for_tickers(['TSLA', 'AAPL', 'NVDA', 'GOOG', 'AMZN', 'MSFT','INTC','BIPC'], models=['LSTM', 'LSTM + Wavelet','LSTM + Sentiment', 'LSTM + Wavelet + Sentiment'], metrics=['MAE', 'MSE', 'RMSE', 'R2']) #'LSTM', 'LSTM + Wavelet',
# Out:
# 2024-11-28 22:12:32.760821: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-28 22:12:33.521994: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-28 22:12:34.617671: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [*********************100%***********************]  1 of 1 completed
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Processing TSLA...
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - loss: 0.4304 - mae: 0.6033
# 2024-11-28 22:12:39.636504: E tensorflow/core/util/util.cc:131] oneDNN supports DT_INT32 only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.4304 - mae: 0.6033 - val_loss: 0.3560 - val_mae: 0.5908
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3057 - mae: 0.5028 - val_loss: 0.1292 - val_mae: 0.3491
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1867 - mae: 0.3812 - val_loss: 0.0079 - val_mae: 0.0881
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0826 - mae: 0.2495 - val_loss: 0.2676 - val_mae: 0.5093
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1113 - mae: 0.2893 - val_loss: 0.4365 - val_mae: 0.6542
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1217 - mae: 0.2759 - val_loss: 0.2783 - val_mae: 0.5194
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1070 - mae: 0.2687 - val_loss: 0.0905 - val_mae: 0.2865
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0736 - mae: 0.2332 - val_loss: 0.0141 - val_mae: 0.0907
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0596 - mae: 0.2136 - val_loss: 0.0114 - val_mae: 0.0899
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0656 - mae: 0.2177 - val_loss: 0.0235 - val_mae: 0.1245
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0725 - mae: 0.2311 - val_loss: 0.0287 - val_mae: 0.1438
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0641 - mae: 0.2247 - val_loss: 0.0247 - val_mae: 0.1291
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0711 - mae: 0.2371 - val_loss: 0.0152 - val_mae: 0.0903
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.4432 - mae: 0.6119 - val_loss: 0.4591 - val_mae: 0.6724
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.3590 - mae: 0.5470 - val_loss: 0.2662 - val_mae: 0.5089
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2574 - mae: 0.4553 - val_loss: 0.0834 - val_mae: 0.2753
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1467 - mae: 0.3305 - val_loss: 0.0109 - val_mae: 0.0892
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0701 - mae: 0.2256 - val_loss: 0.2326 - val_mae: 0.4734
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1227 - mae: 0.2843 - val_loss: 0.3220 - val_mae: 0.5597
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1461 - mae: 0.3040 - val_loss: 0.1896 - val_mae: 0.4254
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0971 - mae: 0.2668 - val_loss: 0.0608 - val_mae: 0.2287
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0692 - mae: 0.2277 - val_loss: 0.0112 - val_mae: 0.0915
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0502 - mae: 0.1892 - val_loss: 0.0116 - val_mae: 0.0907
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0670 - mae: 0.2117 - val_loss: 0.0213 - val_mae: 0.1148
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0725 - mae: 0.2392 - val_loss: 0.0252 - val_mae: 0.1308
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0691 - mae: 0.2170 - val_loss: 0.0214 - val_mae: 0.1149
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0665 - mae: 0.2197 - val_loss: 0.0132 - val_mae: 0.0907
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.4485 - mae: 0.6151 - val_loss: 0.4256 - val_mae: 0.6470
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3455 - mae: 0.5342 - val_loss: 0.1800 - val_mae: 0.4155
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2063 - mae: 0.4011 - val_loss: 0.0146 - val_mae: 0.0886
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0944 - mae: 0.2675 - val_loss: 0.1373 - val_mae: 0.3590
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0733 - mae: 0.2477 - val_loss: 0.4031 - val_mae: 0.6279
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1381 - mae: 0.2972 - val_loss: 0.3139 - val_mae: 0.5522
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1093 - mae: 0.2798 - val_loss: 0.1265 - val_mae: 0.3431
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0668 - mae: 0.2278 - val_loss: 0.0272 - val_mae: 0.1365
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0477 - mae: 0.1852 - val_loss: 0.0084 - val_mae: 0.0917
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0624 - mae: 0.2205 - val_loss: 0.0157 - val_mae: 0.0912
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0672 - mae: 0.2290 - val_loss: 0.0210 - val_mae: 0.1126
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0666 - mae: 0.2248 - val_loss: 0.0166 - val_mae: 0.0915
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0617 - mae: 0.2220 - val_loss: 0.0101 - val_mae: 0.0914
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0535 - mae: 0.2013 - val_loss: 0.0093 - val_mae: 0.0923
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0355 - mae: 0.1558 - val_loss: 0.0188 - val_mae: 0.1006
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0418 - mae: 0.1741 - val_loss: 0.0301 - val_mae: 0.1464
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0531 - mae: 0.1876 - val_loss: 0.0307 - val_mae: 0.1482
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0476 - mae: 0.1661 - val_loss: 0.0191 - val_mae: 0.1018
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0307 - mae: 0.1277 - val_loss: 0.0112 - val_mae: 0.0927
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f6d9450d7e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f6d9450d7e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.4327 - mae: 0.6049 - val_loss: 0.3934 - val_mae: 0.6216
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3187 - mae: 0.5144 - val_loss: 0.1412 - val_mae: 0.3658
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1903 - mae: 0.3830 - val_loss: 0.0080 - val_mae: 0.0884
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0818 - mae: 0.2393 - val_loss: 0.2032 - val_mae: 0.4415
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0838 - mae: 0.2571 - val_loss: 0.4487 - val_mae: 0.6633
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1765 - mae: 0.3153 - val_loss: 0.2774 - val_mae: 0.5183
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1078 - mae: 0.2729 - val_loss: 0.0955 - val_mae: 0.2948
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0652 - mae: 0.2292 - val_loss: 0.0164 - val_mae: 0.0918
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0523 - mae: 0.2013 - val_loss: 0.0113 - val_mae: 0.0910
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0633 - mae: 0.2095 - val_loss: 0.0253 - val_mae: 0.1308
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0736 - mae: 0.2295 - val_loss: 0.0316 - val_mae: 0.1530
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0758 - mae: 0.2319 - val_loss: 0.0266 - val_mae: 0.1354
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0707 - mae: 0.2268 - val_loss: 0.0159 - val_mae: 0.0912
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.4399 - mae: 0.6097 - val_loss: 0.4073 - val_mae: 0.6327
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3325 - mae: 0.5258 - val_loss: 0.1996 - val_mae: 0.4385
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2164 - mae: 0.4134 - val_loss: 0.0336 - val_mae: 0.1612
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1244 - mae: 0.2912 - val_loss: 0.0625 - val_mae: 0.2335
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0718 - mae: 0.2338 - val_loss: 0.3905 - val_mae: 0.6181
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1545 - mae: 0.3109 - val_loss: 0.3471 - val_mae: 0.5819
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1427 - mae: 0.3008 - val_loss: 0.1542 - val_mae: 0.3817
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0943 - mae: 0.2591 - val_loss: 0.0374 - val_mae: 0.1704
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0539 - mae: 0.2076 - val_loss: 0.0082 - val_mae: 0.0906
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0564 - mae: 0.2082 - val_loss: 0.0196 - val_mae: 0.1074
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0728 - mae: 0.2331 - val_loss: 0.0336 - val_mae: 0.1598
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0772 - mae: 0.2367 - val_loss: 0.0365 - val_mae: 0.1686
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0818 - mae: 0.2450 - val_loss: 0.0287 - val_mae: 0.1437
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0663 - mae: 0.2140 - val_loss: 0.0172 - val_mae: 0.0951
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0546 - mae: 0.2028 - val_loss: 0.0090 - val_mae: 0.0909
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0461 - mae: 0.1826 - val_loss: 0.0108 - val_mae: 0.0915
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0418 - mae: 0.1628 - val_loss: 0.0231 - val_mae: 0.1209
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0392 - mae: 0.1629 - val_loss: 0.0384 - val_mae: 0.1726
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0560 - mae: 0.1849 - val_loss: 0.0431 - val_mae: 0.1857
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.4017 - mae: 0.6162 - val_loss: 0.6319 - val_mae: 0.7946
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.3006 - mae: 0.5342 - val_loss: 0.4084 - val_mae: 0.6388
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2061 - mae: 0.4405 - val_loss: 0.1701 - val_mae: 0.4123
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0924 - mae: 0.2982 - val_loss: 0.0068 - val_mae: 0.0825
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0108 - mae: 0.1025 - val_loss: 0.1412 - val_mae: 0.3755
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0486 - mae: 0.2003 - val_loss: 0.2474 - val_mae: 0.4970
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0971 - mae: 0.2861 - val_loss: 0.1198 - val_mae: 0.3458
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0452 - mae: 0.1887 - val_loss: 0.0194 - val_mae: 0.1389
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0063 - mae: 0.0715 - val_loss: 0.0029 - val_mae: 0.0534
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0054 - mae: 0.0629 - val_loss: 0.0330 - val_mae: 0.1816
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0240 - mae: 0.1510 - val_loss: 0.0599 - val_mae: 0.2447
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0318 - mae: 0.1771 - val_loss: 0.0663 - val_mae: 0.2573
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0367 - mae: 0.1878 - val_loss: 0.0531 - val_mae: 0.2304
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0280 - mae: 0.1657 - val_loss: 0.0323 - val_mae: 0.1795
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0231 - mae: 0.1465 - val_loss: 0.0123 - val_mae: 0.1109
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0112 - mae: 0.1040 - val_loss: 6.8711e-04 - val_mae: 0.0262
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0016 - mae: 0.0355 - val_loss: 0.0037 - val_mae: 0.0612
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0022 - mae: 0.0365 - val_loss: 0.0178 - val_mae: 0.1334
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0060 - mae: 0.0715 - val_loss: 0.0319 - val_mae: 0.1786
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0144 - mae: 0.1092 - val_loss: 0.0338 - val_mae: 0.1837
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0119 - mae: 0.1018 - val_loss: 0.0245 - val_mae: 0.1566
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0113 - mae: 0.0999 - val_loss: 0.0108 - val_mae: 0.1038
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0065 - mae: 0.0712 - val_loss: 0.0016 - val_mae: 0.0395
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0024 - mae: 0.0353 - val_loss: 5.6292e-04 - val_mae: 0.0237
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 3.1311e-04 - mae: 0.0145 - val_loss: 0.0060 - val_mae: 0.0774
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0055 - mae: 0.0661 - val_loss: 0.0125 - val_mae: 0.1118
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0070 - mae: 0.0792 - val_loss: 0.0164 - val_mae: 0.1280
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0086 - mae: 0.0895 - val_loss: 0.0162 - val_mae: 0.1274
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0084 - mae: 0.0865 - val_loss: 0.0125 - val_mae: 0.1118
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0073 - mae: 0.0794 - val_loss: 0.0069 - val_mae: 0.0832
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0030 - mae: 0.0473 - val_loss: 0.0023 - val_mae: 0.0477
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0023 - mae: 0.0434 - val_loss: 3.5805e-05 - val_mae: 0.0057
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 3.3286e-04 - mae: 0.0133 - val_loss: 0.0010 - val_mae: 0.0317
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 4.9760e-04 - mae: 0.0195 - val_loss: 0.0042 - val_mae: 0.0650
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0046 - mae: 0.0594 - val_loss: 0.0064 - val_mae: 0.0798
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0022 - mae: 0.0409 - val_loss: 0.0070 - val_mae: 0.0839
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0046 - mae: 0.0625 - val_loss: 0.0051 - val_mae: 0.0715
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0034 - mae: 0.0486 - val_loss: 0.0022 - val_mae: 0.0473
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0014 - mae: 0.0350 - val_loss: 3.9547e-04 - val_mae: 0.0198
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 9.6378e-04 - mae: 0.0242 - val_loss: 8.7297e-05 - val_mae: 0.0091
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 5.3312e-04 - mae: 0.0191 - val_loss: 0.0012 - val_mae: 0.0346
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 9.6525e-04 - mae: 0.0240 - val_loss: 0.0028 - val_mae: 0.0530
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.4043 - mae: 0.6184 - val_loss: 0.5600 - val_mae: 0.7480
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2729 - mae: 0.5090 - val_loss: 0.2803 - val_mae: 0.5292
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1461 - mae: 0.3743 - val_loss: 0.0532 - val_mae: 0.2307
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0416 - mae: 0.2020 - val_loss: 0.0332 - val_mae: 0.1820
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0066 - mae: 0.0631 - val_loss: 0.2954 - val_mae: 0.5430
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1007 - mae: 0.2945 - val_loss: 0.2268 - val_mae: 0.4759
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0746 - mae: 0.2458 - val_loss: 0.0703 - val_mae: 0.2648
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0134 - mae: 0.1030 - val_loss: 0.0043 - val_mae: 0.0656
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0018 - mae: 0.0315 - val_loss: 0.0083 - val_mae: 0.0914
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0116 - mae: 0.1046 - val_loss: 0.0350 - val_mae: 0.1870
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0223 - mae: 0.1484 - val_loss: 0.0533 - val_mae: 0.2309
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0370 - mae: 0.1886 - val_loss: 0.0521 - val_mae: 0.2283
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0339 - mae: 0.1804 - val_loss: 0.0360 - val_mae: 0.1897
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0231 - mae: 0.1504 - val_loss: 0.0155 - val_mae: 0.1243
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0151 - mae: 0.1176 - val_loss: 0.0015 - val_mae: 0.0389
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0036 - mae: 0.0514 - val_loss: 0.0029 - val_mae: 0.0538
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0011 - mae: 0.0291 - val_loss: 0.0194 - val_mae: 0.1392
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0066 - mae: 0.0610 - val_loss: 0.0391 - val_mae: 0.1975
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0148 - mae: 0.1099 - val_loss: 0.0446 - val_mae: 0.2110
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0174 - mae: 0.1184 - val_loss: 0.0331 - val_mae: 0.1818
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0140 - mae: 0.0979 - val_loss: 0.0154 - val_mae: 0.1242
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0052 - mae: 0.0610 - val_loss: 0.0033 - val_mae: 0.0574
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0029 - mae: 0.0408 - val_loss: 8.1911e-05 - val_mae: 0.0090
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0010 - mae: 0.0283 - val_loss: 0.0040 - val_mae: 0.0633
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0031 - mae: 0.0498 - val_loss: 0.0101 - val_mae: 0.1004
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0050 - mae: 0.0674 - val_loss: 0.0145 - val_mae: 0.1202
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0071 - mae: 0.0836 - val_loss: 0.0152 - val_mae: 0.1233
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0063 - mae: 0.0748 - val_loss: 0.0128 - val_mae: 0.1132
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0056 - mae: 0.0720 - val_loss: 0.0082 - val_mae: 0.0907
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0046 - mae: 0.0637 - val_loss: 0.0034 - val_mae: 0.0582
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0024 - mae: 0.0461 - val_loss: 3.5721e-04 - val_mae: 0.0188
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 8.5038e-04 - mae: 0.0182 - val_loss: 4.4253e-04 - val_mae: 0.0210
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.0209e-04 - mae: 0.0095 - val_loss: 0.0034 - val_mae: 0.0579
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.4023 - mae: 0.6165 - val_loss: 0.5607 - val_mae: 0.7485
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2677 - mae: 0.5048 - val_loss: 0.2839 - val_mae: 0.5326
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1500 - mae: 0.3781 - val_loss: 0.0518 - val_mae: 0.2276
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0330 - mae: 0.1810 - val_loss: 0.0376 - val_mae: 0.1938
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0119 - mae: 0.0892 - val_loss: 0.2300 - val_mae: 0.4792
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0818 - mae: 0.2627 - val_loss: 0.1673 - val_mae: 0.4087
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0698 - mae: 0.2394 - val_loss: 0.0397 - val_mae: 0.1990
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0082 - mae: 0.0779 - val_loss: 8.1509e-05 - val_mae: 0.0084
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0042 - mae: 0.0584 - val_loss: 0.0170 - val_mae: 0.1306
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0161 - mae: 0.1253 - val_loss: 0.0428 - val_mae: 0.2068
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0260 - mae: 0.1599 - val_loss: 0.0534 - val_mae: 0.2310
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0295 - mae: 0.1688 - val_loss: 0.0458 - val_mae: 0.2140
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0307 - mae: 0.1738 - val_loss: 0.0272 - val_mae: 0.1648
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0177 - mae: 0.1315 - val_loss: 0.0085 - val_mae: 0.0923
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0080 - mae: 0.0881 - val_loss: 1.7182e-05 - val_mae: 0.0040
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0014 - mae: 0.0332 - val_loss: 0.0070 - val_mae: 0.0838
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0036 - mae: 0.0467 - val_loss: 0.0226 - val_mae: 0.1502
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0058 - mae: 0.0641 - val_loss: 0.0353 - val_mae: 0.1879
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0160 - mae: 0.1149 - val_loss: 0.0324 - val_mae: 0.1800
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0144 - mae: 0.1037 - val_loss: 0.0187 - val_mae: 0.1368
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0065 - mae: 0.0756 - val_loss: 0.0060 - val_mae: 0.0776
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0033 - mae: 0.0453 - val_loss: 1.8527e-04 - val_mae: 0.0136
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 8.5729e-04 - mae: 0.0265 - val_loss: 0.0017 - val_mae: 0.0416
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0024 - mae: 0.0437 - val_loss: 0.0064 - val_mae: 0.0799
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0062 - mae: 0.0732 - val_loss: 0.0098 - val_mae: 0.0988
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.4045 - mae: 0.6177 - val_loss: 0.5113 - val_mae: 0.7147
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2447 - mae: 0.4838 - val_loss: 0.1813 - val_mae: 0.4257
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1006 - mae: 0.3105 - val_loss: 0.0013 - val_mae: 0.0355
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0062 - mae: 0.0732 - val_loss: 0.1902 - val_mae: 0.4357
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0599 - mae: 0.2235 - val_loss: 0.2533 - val_mae: 0.5028
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0759 - mae: 0.2533 - val_loss: 0.1173 - val_mae: 0.3421
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0296 - mae: 0.1514 - val_loss: 0.0170 - val_mae: 0.1302
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0073 - mae: 0.0675 - val_loss: 0.0039 - val_mae: 0.0628
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0075 - mae: 0.0791 - val_loss: 0.0360 - val_mae: 0.1897
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0282 - mae: 0.1616 - val_loss: 0.0609 - val_mae: 0.2468
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0420 - mae: 0.2021 - val_loss: 0.0615 - val_mae: 0.2479
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0395 - mae: 0.1960 - val_loss: 0.0431 - val_mae: 0.2076
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0243 - mae: 0.1533 - val_loss: 0.0194 - val_mae: 0.1391
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.3996 - mae: 0.6141 - val_loss: 0.5941 - val_mae: 0.7704
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.2889 - mae: 0.5237 - val_loss: 0.3504 - val_mae: 0.5917
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1809 - mae: 0.4148 - val_loss: 0.1173 - val_mae: 0.3425
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0636 - mae: 0.2494 - val_loss: 1.8060e-04 - val_mae: 0.0128
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0029 - mae: 0.0473 - val_loss: 0.2058 - val_mae: 0.4533
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0627 - mae: 0.2283 - val_loss: 0.2598 - val_mae: 0.5092
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0849 - mae: 0.2689 - val_loss: 0.1191 - val_mae: 0.3448
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0321 - mae: 0.1584 - val_loss: 0.0194 - val_mae: 0.1389
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0040 - mae: 0.0504 - val_loss: 0.0014 - val_mae: 0.0373
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0047 - mae: 0.0658 - val_loss: 0.0244 - val_mae: 0.1562
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0190 - mae: 0.1371 - val_loss: 0.0475 - val_mae: 0.2178
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0272 - mae: 0.1618 - val_loss: 0.0546 - val_mae: 0.2335
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0313 - mae: 0.1738 - val_loss: 0.0452 - val_mae: 0.2126
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0324 - mae: 0.1761 - val_loss: 0.0255 - val_mae: 0.1596
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# [*********************100%***********************]  1 of 1 completed
# Processing AAPL...
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0808 - mae: 0.2436 - val_loss: 0.0734 - val_mae: 0.2441
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0501 - mae: 0.1740 - val_loss: 0.0284 - val_mae: 0.1198
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0310 - mae: 0.1460 - val_loss: 0.0152 - val_mae: 0.1223
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0403 - mae: 0.1875 - val_loss: 0.0153 - val_mae: 0.1216
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0347 - mae: 0.1689 - val_loss: 0.0152 - val_mae: 0.1199
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0323 - mae: 0.1680 - val_loss: 0.0218 - val_mae: 0.1182
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0277 - mae: 0.1449 - val_loss: 0.0304 - val_mae: 0.1292
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0289 - mae: 0.1391 - val_loss: 0.0341 - val_mae: 0.1432
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0324 - mae: 0.1417 - val_loss: 0.0311 - val_mae: 0.1322
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0265 - mae: 0.1317 - val_loss: 0.0249 - val_mae: 0.1168
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0257 - mae: 0.1346 - val_loss: 0.0189 - val_mae: 0.1172
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0239 - mae: 0.1365 - val_loss: 0.0151 - val_mae: 0.1175
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0209 - mae: 0.1378 - val_loss: 0.0140 - val_mae: 0.1178
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0214 - mae: 0.1395 - val_loss: 0.0139 - val_mae: 0.1177
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0262 - mae: 0.1547 - val_loss: 0.0144 - val_mae: 0.1174
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0237 - mae: 0.1463 - val_loss: 0.0164 - val_mae: 0.1168
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0184 - mae: 0.1250 - val_loss: 0.0197 - val_mae: 0.1164
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0203 - mae: 0.1261 - val_loss: 0.0229 - val_mae: 0.1160
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0208 - mae: 0.1195 - val_loss: 0.0238 - val_mae: 0.1159
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0223 - mae: 0.1294 - val_loss: 0.0235 - val_mae: 0.1158
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0214 - mae: 0.1200 - val_loss: 0.0215 - val_mae: 0.1158
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0210 - mae: 0.1212 - val_loss: 0.0193 - val_mae: 0.1160
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0202 - mae: 0.1206 - val_loss: 0.0172 - val_mae: 0.1161
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0197 - mae: 0.1252 - val_loss: 0.0161 - val_mae: 0.1163
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0899 - mae: 0.2655 - val_loss: 0.1004 - val_mae: 0.2948
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0649 - mae: 0.2074 - val_loss: 0.0628 - val_mae: 0.2213
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0430 - mae: 0.1595 - val_loss: 0.0282 - val_mae: 0.1196
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0338 - mae: 0.1523 - val_loss: 0.0149 - val_mae: 0.1219
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0335 - mae: 0.1689 - val_loss: 0.0174 - val_mae: 0.1223
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0415 - mae: 0.1872 - val_loss: 0.0150 - val_mae: 0.1209
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0342 - mae: 0.1759 - val_loss: 0.0154 - val_mae: 0.1192
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0275 - mae: 0.1546 - val_loss: 0.0208 - val_mae: 0.1179
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0252 - mae: 0.1403 - val_loss: 0.0274 - val_mae: 0.1171
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0279 - mae: 0.1404 - val_loss: 0.0320 - val_mae: 0.1360
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0280 - mae: 0.1330 - val_loss: 0.0330 - val_mae: 0.1397
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0278 - mae: 0.1287 - val_loss: 0.0306 - val_mae: 0.1312
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0278 - mae: 0.1333 - val_loss: 0.0260 - val_mae: 0.1160
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0240 - mae: 0.1261 - val_loss: 0.0211 - val_mae: 0.1162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0849 - mae: 0.2530 - val_loss: 0.1008 - val_mae: 0.2954
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0648 - mae: 0.2060 - val_loss: 0.0619 - val_mae: 0.2191
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0426 - mae: 0.1643 - val_loss: 0.0272 - val_mae: 0.1199
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0288 - mae: 0.1424 - val_loss: 0.0150 - val_mae: 0.1222
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0349 - mae: 0.1732 - val_loss: 0.0170 - val_mae: 0.1224
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0439 - mae: 0.1912 - val_loss: 0.0148 - val_mae: 0.1211
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0324 - mae: 0.1696 - val_loss: 0.0160 - val_mae: 0.1195
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0276 - mae: 0.1563 - val_loss: 0.0221 - val_mae: 0.1181
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0249 - mae: 0.1363 - val_loss: 0.0289 - val_mae: 0.1230
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0282 - mae: 0.1349 - val_loss: 0.0326 - val_mae: 0.1380
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0279 - mae: 0.1351 - val_loss: 0.0331 - val_mae: 0.1397
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0265 - mae: 0.1274 - val_loss: 0.0303 - val_mae: 0.1296
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0263 - mae: 0.1321 - val_loss: 0.0260 - val_mae: 0.1165
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0253 - mae: 0.1339 - val_loss: 0.0213 - val_mae: 0.1168
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0222 - mae: 0.1305 - val_loss: 0.0175 - val_mae: 0.1170
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0243 - mae: 0.1461 - val_loss: 0.0154 - val_mae: 0.1172
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0853 - mae: 0.2543 - val_loss: 0.0911 - val_mae: 0.2780
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0607 - mae: 0.1945 - val_loss: 0.0507 - val_mae: 0.1911
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0400 - mae: 0.1588 - val_loss: 0.0209 - val_mae: 0.1216
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0297 - mae: 0.1518 - val_loss: 0.0156 - val_mae: 0.1234
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0356 - mae: 0.1738 - val_loss: 0.0160 - val_mae: 0.1231
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0387 - mae: 0.1809 - val_loss: 0.0150 - val_mae: 0.1213
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0300 - mae: 0.1646 - val_loss: 0.0193 - val_mae: 0.1195
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0295 - mae: 0.1517 - val_loss: 0.0278 - val_mae: 0.1182
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0291 - mae: 0.1381 - val_loss: 0.0341 - val_mae: 0.1426
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0296 - mae: 0.1355 - val_loss: 0.0343 - val_mae: 0.1437
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0289 - mae: 0.1327 - val_loss: 0.0302 - val_mae: 0.1285
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0269 - mae: 0.1299 - val_loss: 0.0240 - val_mae: 0.1173
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0237 - mae: 0.1328 - val_loss: 0.0188 - val_mae: 0.1176
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0245 - mae: 0.1400 - val_loss: 0.0156 - val_mae: 0.1180
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0228 - mae: 0.1422 - val_loss: 0.0144 - val_mae: 0.1182
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0215 - mae: 0.1389 - val_loss: 0.0141 - val_mae: 0.1182
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0246 - mae: 0.1472 - val_loss: 0.0144 - val_mae: 0.1179
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0243 - mae: 0.1506 - val_loss: 0.0157 - val_mae: 0.1175
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0223 - mae: 0.1404 - val_loss: 0.0183 - val_mae: 0.1170
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0195 - mae: 0.1229 - val_loss: 0.0213 - val_mae: 0.1167
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0201 - mae: 0.1233 - val_loss: 0.0241 - val_mae: 0.1164
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0227 - mae: 0.1267 - val_loss: 0.0250 - val_mae: 0.1163
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0210 - mae: 0.1171 - val_loss: 0.0238 - val_mae: 0.1163
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0225 - mae: 0.1251 - val_loss: 0.0216 - val_mae: 0.1163
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0189 - mae: 0.1181 - val_loss: 0.0189 - val_mae: 0.1165
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0213 - mae: 0.1304 - val_loss: 0.0171 - val_mae: 0.1166
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0851 - mae: 0.2536 - val_loss: 0.0911 - val_mae: 0.2781
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0608 - mae: 0.1952 - val_loss: 0.0525 - val_mae: 0.1958
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0391 - mae: 0.1599 - val_loss: 0.0220 - val_mae: 0.1216
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0304 - mae: 0.1480 - val_loss: 0.0157 - val_mae: 0.1235
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0382 - mae: 0.1782 - val_loss: 0.0160 - val_mae: 0.1226
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0396 - mae: 0.1821 - val_loss: 0.0148 - val_mae: 0.1207
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0323 - mae: 0.1710 - val_loss: 0.0191 - val_mae: 0.1190
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0271 - mae: 0.1447 - val_loss: 0.0263 - val_mae: 0.1177
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0273 - mae: 0.1378 - val_loss: 0.0316 - val_mae: 0.1338
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0277 - mae: 0.1304 - val_loss: 0.0324 - val_mae: 0.1369
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0261 - mae: 0.1263 - val_loss: 0.0293 - val_mae: 0.1253
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0262 - mae: 0.1301 - val_loss: 0.0244 - val_mae: 0.1169
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0240 - mae: 0.1275 - val_loss: 0.0194 - val_mae: 0.1172
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0231 - mae: 0.1381 - val_loss: 0.0161 - val_mae: 0.1174
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0269 - mae: 0.1535 - val_loss: 0.0147 - val_mae: 0.1176
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0232 - mae: 0.1449 - val_loss: 0.0144 - val_mae: 0.1177
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0237 - mae: 0.1468 - val_loss: 0.0145 - val_mae: 0.1175
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0204 - mae: 0.1365 - val_loss: 0.0152 - val_mae: 0.1172
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0221 - mae: 0.1415 - val_loss: 0.0165 - val_mae: 0.1170
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0226 - mae: 0.1407 - val_loss: 0.0188 - val_mae: 0.1166
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0180 - mae: 0.1201 - val_loss: 0.0212 - val_mae: 0.1164
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0218 - mae: 0.1284 - val_loss: 0.0232 - val_mae: 0.1162
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0205 - mae: 0.1199 - val_loss: 0.0238 - val_mae: 0.1161
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0216 - mae: 0.1247 - val_loss: 0.0230 - val_mae: 0.1161
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0208 - mae: 0.1205 - val_loss: 0.0209 - val_mae: 0.1162
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0217 - mae: 0.1272 - val_loss: 0.0186 - val_mae: 0.1164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.0056 - mae: 0.0555 - val_loss: 0.0444 - val_mae: 0.2091
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0033 - mae: 0.0404 - val_loss: 0.0313 - val_mae: 0.1753
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0034 - mae: 0.0519 - val_loss: 0.0282 - val_mae: 0.1662
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0032 - mae: 0.0519 - val_loss: 0.0307 - val_mae: 0.1733
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0028 - mae: 0.0460 - val_loss: 0.0354 - val_mae: 0.1860
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0023 - mae: 0.0377 - val_loss: 0.0386 - val_mae: 0.1943
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0024 - mae: 0.0372 - val_loss: 0.0385 - val_mae: 0.1940
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0023 - mae: 0.0365 - val_loss: 0.0362 - val_mae: 0.1878
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0022 - mae: 0.0368 - val_loss: 0.0326 - val_mae: 0.1776
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0021 - mae: 0.0375 - val_loss: 0.0289 - val_mae: 0.1670
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0021 - mae: 0.0389 - val_loss: 0.0271 - val_mae: 0.1612
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0021 - mae: 0.0384 - val_loss: 0.0272 - val_mae: 0.1614
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0018 - mae: 0.0367 - val_loss: 0.0292 - val_mae: 0.1672
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0016 - mae: 0.0345 - val_loss: 0.0322 - val_mae: 0.1760
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0015 - mae: 0.0338 - val_loss: 0.0345 - val_mae: 0.1823
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0016 - mae: 0.0313 - val_loss: 0.0349 - val_mae: 0.1833
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0016 - mae: 0.0317 - val_loss: 0.0335 - val_mae: 0.1790
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0013 - mae: 0.0295 - val_loss: 0.0300 - val_mae: 0.1688
# Epoch 19/100
# ...
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0162 - mae: 0.1163 - val_loss: 0.0248 - val_mae: 0.1569
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0127 - mae: 0.1000 - val_loss: 0.0707 - val_mae: 0.2655
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0188 - mae: 0.1076 - val_loss: 0.1180 - val_mae: 0.3433
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0289 - mae: 0.1404 - val_loss: 0.1390 - val_mae: 0.3726
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.8466 - mae: 0.9108 - val_loss: 0.6571 - val_mae: 0.8106
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.5929 - mae: 0.7654 - val_loss: 0.3088 - val_mae: 0.5556
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.3353 - mae: 0.5777 - val_loss: 0.0420 - val_mae: 0.2045
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1041 - mae: 0.3183 - val_loss: 0.0774 - val_mae: 0.2777
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0155 - mae: 0.1092 - val_loss: 0.5821 - val_mae: 0.7627
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1836 - mae: 0.3649 - val_loss: 0.5500 - val_mae: 0.7414
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1773 - mae: 0.3631 - val_loss: 0.2424 - val_mae: 0.4921
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0548 - mae: 0.1980 - val_loss: 0.0476 - val_mae: 0.2177
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0162 - mae: 0.1043 - val_loss: 1.6079e-04 - val_mae: 0.0122
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0362 - mae: 0.1743 - val_loss: 0.0157 - val_mae: 0.1248
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0856 - mae: 0.2877 - val_loss: 0.0283 - val_mae: 0.1680
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0868 - mae: 0.2909 - val_loss: 0.0232 - val_mae: 0.1519
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0691 - mae: 0.2563 - val_loss: 0.0090 - val_mae: 0.0943
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0603 - mae: 0.2402 - val_loss: 1.3741e-04 - val_mae: 0.0114
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0350 - mae: 0.1757 - val_loss: 0.0126 - val_mae: 0.1118
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0158 - mae: 0.1109 - val_loss: 0.0491 - val_mae: 0.2213
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0127 - mae: 0.0885 - val_loss: 0.0969 - val_mae: 0.3109
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0371 - mae: 0.1528 - val_loss: 0.1239 - val_mae: 0.3518
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0317 - mae: 0.1503 - val_loss: 0.1210 - val_mae: 0.3476
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0199 - mae: 0.1206 - val_loss: 0.1004 - val_mae: 0.3166
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0270 - mae: 0.1378 - val_loss: 0.0648 - val_mae: 0.2543
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0173 - mae: 0.0999 - val_loss: 0.0336 - val_mae: 0.1830
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0079 - mae: 0.0716 - val_loss: 0.0136 - val_mae: 0.1159
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0082 - mae: 0.0743 - val_loss: 0.0034 - val_mae: 0.0575
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# [*********************100%***********************]  1 of 1 completed
# Processing GOOG...
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.6343 - mae: 0.7681 - val_loss: 0.1499 - val_mae: 0.3758
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4539 - mae: 0.6419 - val_loss: 0.0416 - val_mae: 0.1773
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2868 - mae: 0.4950 - val_loss: 0.0282 - val_mae: 0.1235
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1097 - mae: 0.2904 - val_loss: 0.3380 - val_mae: 0.5661
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0759 - mae: 0.2119 - val_loss: 0.7747 - val_mae: 0.8681
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1706 - mae: 0.3335 - val_loss: 0.6346 - val_mae: 0.7839
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1863 - mae: 0.3195 - val_loss: 0.3088 - val_mae: 0.5398
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0615 - mae: 0.1934 - val_loss: 0.1224 - val_mae: 0.3276
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0565 - mae: 0.2200 - val_loss: 0.0514 - val_mae: 0.1940
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0884 - mae: 0.2657 - val_loss: 0.0306 - val_mae: 0.1320
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0981 - mae: 0.2815 - val_loss: 0.0291 - val_mae: 0.1262
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0971 - mae: 0.2666 - val_loss: 0.0399 - val_mae: 0.1625
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0881 - mae: 0.2629 - val_loss: 0.0663 - val_mae: 0.2285
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.6494 - mae: 0.7758 - val_loss: 0.1421 - val_mae: 0.3653
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.4621 - mae: 0.6475 - val_loss: 0.0369 - val_mae: 0.1632
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2823 - mae: 0.4879 - val_loss: 0.0281 - val_mae: 0.1237
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.1128 - mae: 0.2875 - val_loss: 0.2855 - val_mae: 0.5183
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0652 - mae: 0.2036 - val_loss: 0.6977 - val_mae: 0.8230
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1857 - mae: 0.3434 - val_loss: 0.6158 - val_mae: 0.7720
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1675 - mae: 0.3080 - val_loss: 0.3523 - val_mae: 0.5784
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0949 - mae: 0.2374 - val_loss: 0.1542 - val_mae: 0.3723
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0731 - mae: 0.2494 - val_loss: 0.0614 - val_mae: 0.2176
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0738 - mae: 0.2366 - val_loss: 0.0306 - val_mae: 0.1315
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1039 - mae: 0.2808 - val_loss: 0.0240 - val_mae: 0.1140
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0997 - mae: 0.2715 - val_loss: 0.0271 - val_mae: 0.1184
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1001 - mae: 0.2746 - val_loss: 0.0406 - val_mae: 0.1645
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0804 - mae: 0.2467 - val_loss: 0.0702 - val_mae: 0.2367
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0666 - mae: 0.2298 - val_loss: 0.1185 - val_mae: 0.3216
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0546 - mae: 0.2136 - val_loss: 0.1860 - val_mae: 0.4124
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0507 - mae: 0.2029 - val_loss: 0.2595 - val_mae: 0.4927
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0630 - mae: 0.1989 - val_loss: 0.3109 - val_mae: 0.5418
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0683 - mae: 0.1919 - val_loss: 0.3182 - val_mae: 0.5484
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0770 - mae: 0.2058 - val_loss: 0.2793 - val_mae: 0.5121
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0650 - mae: 0.1883 - val_loss: 0.2201 - val_mae: 0.4513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.6850 - mae: 0.7993 - val_loss: 0.1921 - val_mae: 0.4289
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step - loss: 0.5161 - mae: 0.6877 - val_loss: 0.0880 - val_mae: 0.2806
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step - loss: 0.3645 - mae: 0.5681 - val_loss: 0.0156 - val_mae: 0.1055
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step - loss: 0.2052 - mae: 0.4053 - val_loss: 0.0694 - val_mae: 0.2355
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0792 - mae: 0.2584 - val_loss: 0.4259 - val_mae: 0.6385
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.0831 - mae: 0.2234 - val_loss: 0.7993 - val_mae: 0.8822
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step - loss: 0.1903 - mae: 0.3528 - val_loss: 0.6592 - val_mae: 0.7994
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step - loss: 0.1916 - mae: 0.3450 - val_loss: 0.3699 - val_mae: 0.5934
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step - loss: 0.0970 - mae: 0.2411 - val_loss: 0.1689 - val_mae: 0.3914
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 734ms/step - loss: 0.0538 - mae: 0.2114 - val_loss: 0.0748 - val_mae: 0.2461
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step - loss: 0.0708 - mae: 0.2394 - val_loss: 0.0373 - val_mae: 0.1547
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step - loss: 0.0922 - mae: 0.2668 - val_loss: 0.0255 - val_mae: 0.1138
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 779ms/step - loss: 0.1101 - mae: 0.2784 - val_loss: 0.0244 - val_mae: 0.1135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 855ms/step
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.6436 - mae: 0.7733 - val_loss: 0.1444 - val_mae: 0.3683
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.4558 - mae: 0.6435 - val_loss: 0.0357 - val_mae: 0.1596
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2736 - mae: 0.4799 - val_loss: 0.0301 - val_mae: 0.1317
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1147 - mae: 0.2920 - val_loss: 0.3045 - val_mae: 0.5365
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0848 - mae: 0.2291 - val_loss: 0.7380 - val_mae: 0.8473
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1689 - mae: 0.3293 - val_loss: 0.6524 - val_mae: 0.7955
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1542 - mae: 0.3034 - val_loss: 0.3802 - val_mae: 0.6022
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0895 - mae: 0.2348 - val_loss: 0.1763 - val_mae: 0.4011
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0552 - mae: 0.2125 - val_loss: 0.0733 - val_mae: 0.2435
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0711 - mae: 0.2259 - val_loss: 0.0372 - val_mae: 0.1549
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0991 - mae: 0.2870 - val_loss: 0.0286 - val_mae: 0.1249
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1065 - mae: 0.2809 - val_loss: 0.0328 - val_mae: 0.1403
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1033 - mae: 0.2861 - val_loss: 0.0485 - val_mae: 0.1869
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0770 - mae: 0.2443 - val_loss: 0.0797 - val_mae: 0.2561
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0646 - mae: 0.2276 - val_loss: 0.1288 - val_mae: 0.3373
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0596 - mae: 0.2213 - val_loss: 0.1873 - val_mae: 0.4142
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0576 - mae: 0.2055 - val_loss: 0.2426 - val_mae: 0.4756
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0571 - mae: 0.2013 - val_loss: 0.2799 - val_mae: 0.5130
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0616 - mae: 0.1868 - val_loss: 0.2786 - val_mae: 0.5118
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0543 - mae: 0.1771 - val_loss: 0.2506 - val_mae: 0.4839
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0639 - mae: 0.1976 - val_loss: 0.2017 - val_mae: 0.4310
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.6220 - mae: 0.7590 - val_loss: 0.1172 - val_mae: 0.3288
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.4054 - mae: 0.6067 - val_loss: 0.0156 - val_mae: 0.1073
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2125 - mae: 0.4108 - val_loss: 0.1173 - val_mae: 0.3193
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0679 - mae: 0.2333 - val_loss: 0.6377 - val_mae: 0.7854
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1475 - mae: 0.2973 - val_loss: 0.7390 - val_mae: 0.8469
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2114 - mae: 0.3507 - val_loss: 0.4446 - val_mae: 0.6522
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0959 - mae: 0.2252 - val_loss: 0.2016 - val_mae: 0.4300
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0532 - mae: 0.1994 - val_loss: 0.0790 - val_mae: 0.2535
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0707 - mae: 0.2307 - val_loss: 0.0382 - val_mae: 0.1562
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0986 - mae: 0.2753 - val_loss: 0.0288 - val_mae: 0.1239
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1028 - mae: 0.2855 - val_loss: 0.0326 - val_mae: 0.1382
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1015 - mae: 0.2853 - val_loss: 0.0501 - val_mae: 0.1898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# Epoch 1/100
# /home/mili/.local/lib/python3.10/site-packages/pywt/_multilevel.py:43: UserWarning: Level value of 8 is too high: all coefficients will experience boundary effects.
#   warnings.warn(
# /home/mili/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
